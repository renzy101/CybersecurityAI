# %% [markdown]
# # TextAttack CLARE
#
# Replication of the training, evaluating, and attacking a model using TextAttack recipe CLARE.

# %%
# !pip install textattack[tensorflow,optional]
# Out:
# Requirement already satisfied: textattack[optional,tensorflow] in /usr/local/lib/python3.10/dist-packages (0.3.9)
# Requirement already satisfied: bert-score>=0.3.5 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (0.3.13)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (0.6.2)
# Requirement already satisfied: flair in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (0.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (3.13.1)
# Requirement already satisfied: language-tool-python in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (2.7.1)
# Requirement already satisfied: lemminflect in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (0.2.3)
# Requirement already satisfied: lru-dict in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (1.3.0)
# Requirement already satisfied: datasets>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (2.15.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (3.8.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (1.23.5)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (1.5.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (1.11.4)
# Requirement already satisfied: torch!=1.8,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (2.1.0+cu121)
# Requirement already satisfied: transformers>=4.30.0 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (4.35.2)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (3.1.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (4.66.1)
# Requirement already satisfied: word2number in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (1.1)
# Requirement already satisfied: num2words in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (0.5.13)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (10.1.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (1.7.1)
# Requirement already satisfied: pinyin>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (0.4.0)
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (0.42.1)
# Requirement already satisfied: OpenHowNet in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (2.0)
# Requirement already satisfied: pycld2 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (0.41)
# Requirement already satisfied: click<8.1.0 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (8.0.4)
# Requirement already satisfied: tensorflow==2.9.1 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (2.9.1)
# Requirement already satisfied: tensorflow-hub in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (0.15.0)
# Requirement already satisfied: tensorflow-text>=2 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (2.9.0)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (2.6)
# Collecting tensorflow-estimator==2.9.0 (from textattack[optional,tensorflow])
#   Using cached tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
# Requirement already satisfied: sentence-transformers==2.2.0 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (2.2.0)
# Requirement already satisfied: stanza in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (1.7.0)
# Requirement already satisfied: visdom in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (0.2.4)
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (0.16.1)
# Requirement already satisfied: gensim==4.1.2 in /usr/local/lib/python3.10/dist-packages (from textattack[optional,tensorflow]) (4.1.2)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim==4.1.2->textattack[optional,tensorflow]) (6.4.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.0->textattack[optional,tensorflow]) (0.16.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.0->textattack[optional,tensorflow]) (1.2.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.0->textattack[optional,tensorflow]) (0.1.99)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.0->textattack[optional,tensorflow]) (0.19.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (1.6.3)
# Collecting flatbuffers<2,>=1.12 (from tensorflow==2.9.1->textattack[optional,tensorflow])
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (1.60.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (3.9.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (23.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (1.16.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (2.9.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (0.34.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1->textattack[optional,tensorflow]) (1.14.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score>=0.3.5->textattack[optional,tensorflow]) (2.31.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score>=0.3.5->textattack[optional,tensorflow]) (3.7.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack[optional,tensorflow]) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack[optional,tensorflow]) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack[optional,tensorflow]) (0.3.7)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack[optional,tensorflow]) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack[optional,tensorflow]) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack[optional,tensorflow]) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack[optional,tensorflow]) (3.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.4.0->textattack[optional,tensorflow]) (6.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->textattack[optional,tensorflow]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->textattack[optional,tensorflow]) (2023.3.post1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack[optional,tensorflow]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack[optional,tensorflow]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack[optional,tensorflow]) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.8,>=1.7.0->textattack[optional,tensorflow]) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.30.0->textattack[optional,tensorflow]) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.30.0->textattack[optional,tensorflow]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.30.0->textattack[optional,tensorflow]) (0.4.1)
# Requirement already satisfied: segtok>=1.5.7 in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (1.5.11)
# Requirement already satisfied: mpld3==0.3 in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (0.3)
# Requirement already satisfied: sqlitedict>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (2.1.0)
# Requirement already satisfied: deprecated>=1.2.4 in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (1.2.14)
# Requirement already satisfied: hyperopt>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (0.2.7)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (1.34.2)
# Requirement already satisfied: bpemb>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (0.3.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (0.9.0)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (1.0.9)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (4.9.3)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (6.1.3)
# Requirement already satisfied: janome in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (0.5.0)
# Requirement already satisfied: gdown==4.4.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (4.4.0)
# Requirement already satisfied: conllu>=4.0 in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (4.5.3)
# Requirement already satisfied: wikipedia-api in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (0.6.0)
# Requirement already satisfied: pptree in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (3.1)
# Requirement already satisfied: pytorch-revgrad in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (0.2.0)
# Requirement already satisfied: transformer-smaller-training-vocab>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from flair->textattack[optional,tensorflow]) (0.3.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown==4.4.0->flair->textattack[optional,tensorflow]) (4.11.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->textattack[optional,tensorflow]) (1.3.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from num2words->textattack[optional,tensorflow]) (0.6.2)
# Requirement already satisfied: anytree in /usr/local/lib/python3.10/dist-packages (from OpenHowNet->textattack[optional,tensorflow]) (2.12.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (from stanza->textattack[optional,tensorflow]) (2.9.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from stanza->textattack[optional,tensorflow]) (0.10.2)
# Requirement already satisfied: tornado in /usr/local/lib/python3.10/dist-packages (from visdom->textattack[optional,tensorflow]) (6.3.2)
# Requirement already satisfied: jsonpatch in /usr/local/lib/python3.10/dist-packages (from visdom->textattack[optional,tensorflow]) (1.33)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from visdom->textattack[optional,tensorflow]) (1.7.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from visdom->textattack[optional,tensorflow]) (9.4.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->textattack[optional,tensorflow]) (3.1.40)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->textattack[optional,tensorflow]) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb->textattack[optional,tensorflow]) (1.39.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb->textattack[optional,tensorflow]) (0.4.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb->textattack[optional,tensorflow]) (1.3.3)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb->textattack[optional,tensorflow]) (1.4.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.9.1->textattack[optional,tensorflow]) (0.42.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack[optional,tensorflow]) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack[optional,tensorflow]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack[optional,tensorflow]) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack[optional,tensorflow]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack[optional,tensorflow]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.4.0->textattack[optional,tensorflow]) (4.0.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb->textattack[optional,tensorflow]) (4.0.11)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair->textattack[optional,tensorflow]) (0.18.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair->textattack[optional,tensorflow]) (2.2.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.7->flair->textattack[optional,tensorflow]) (0.10.9.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack[optional,tensorflow]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack[optional,tensorflow]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack[optional,tensorflow]) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack[optional,tensorflow]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score>=0.3.5->textattack[optional,tensorflow]) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score>=0.3.5->textattack[optional,tensorflow]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score>=0.3.5->textattack[optional,tensorflow]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score>=0.3.5->textattack[optional,tensorflow]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score>=0.3.5->textattack[optional,tensorflow]) (2023.11.17)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers==2.2.0->textattack[optional,tensorflow]) (3.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[optional,tensorflow]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[optional,tensorflow]) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[optional,tensorflow]) (3.5.1)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[optional,tensorflow])
#   Using cached tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[optional,tensorflow]) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[optional,tensorflow]) (3.0.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.2 in /usr/local/lib/python3.10/dist-packages (from boto3->flair->textattack[optional,tensorflow]) (1.34.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3->flair->textattack[optional,tensorflow]) (1.0.1)
# Requirement already satisfied: s3transfer<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from boto3->flair->textattack[optional,tensorflow]) (0.9.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /usr/local/lib/python3.10/dist-packages (from ftfy->flair->textattack[optional,tensorflow]) (0.2.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.8,>=1.7.0->textattack[optional,tensorflow]) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch->visdom->textattack[optional,tensorflow]) (2.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.8,>=1.7.0->textattack[optional,tensorflow]) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->textattack[optional,tensorflow]) (5.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[optional,tensorflow]) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[optional,tensorflow]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[optional,tensorflow]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[optional,tensorflow]) (1.3.1)
# Requirement already satisfied: accelerate>=0.20.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.30.0->textattack[optional,tensorflow]) (0.25.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown==4.4.0->flair->textattack[optional,tensorflow]) (2.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[optional,tensorflow]) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1->textattack[optional,tensorflow]) (3.2.2)
# Installing collected packages: flatbuffers, tensorflow-estimator, tensorboard-data-server
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.5.26
#     Uninstalling flatbuffers-23.5.26:
#       Successfully uninstalled flatbuffers-23.5.26
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
# Successfully installed flatbuffers-1.12 tensorboard-data-server-0.6.1 tensorflow-estimator-2.9.0

# %%
# !pip install tensorflow==2.14
# Out:
# Requirement already satisfied: tensorflow==2.14 in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (4.25.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (1.60.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.14) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow==2.14) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14) (3.2.2)

# %% [markdown]
# ## Training
#
# First, we're going to train a model. TextAttack integrates directly with [transformers](https://github.com/huggingface/transformers/) and [datasets](https://github.com/huggingface/datasets) to train any of the `transformers` pre-trained models on datasets from `datasets`.
#
# Let's use the AG News dataset: it's relatively short, and showcases the key features of `textattack train`. Let's take a look at the dataset using `textattack peek-dataset`:

# %%
# !textattack peek-dataset --dataset-from-huggingface ag_news
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.7.0.json: 370kB [00:00, 15.4MB/s]
# 2023-12-17 15:55:15 INFO: Downloading default packages for language: en (English) ...
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.7.0/models/default.zip: 100% 527M/527M [00:02<00:00, 220MB/s]
# 2023-12-17 15:55:24 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2023-12-17 15:55:27.493211: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 15:55:27.493289: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 15:55:27.493385: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 15:55:28.742466: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-17 15:55:33.512682: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Downloading builder script: 100% 4.06k/4.06k [00:00<00:00, 21.5MB/s]
# Downloading metadata: 100% 2.65k/2.65k [00:00<00:00, 13.9MB/s]
# Downloading readme: 100% 7.95k/7.95k [00:00<00:00, 28.0MB/s]
# Downloading data: 29.5MB [00:00, 41.1MB/s]
# Downloading data: 1.86MB [00:00, 19.7MB/s]
# Generating train split: 100% 120000/120000 [00:04<00:00, 28799.67 examples/s]
# Generating test split: 100% 7600/7600 [00:00<00:00, 36439.06 examples/s]
# textattack: Loading datasets dataset ag_news, split train.
# textattack: Number of samples: 120000
# textattack: Number of words per input:
# textattack: 	total:   4653536
# textattack: 	mean:    38.78
# textattack: 	std:     11.18
# textattack: 	min:     11
# textattack: 	max:     178
# textattack: Dataset lowercased: False
# textattack: First sample:
# Wall St. Bears Claw Back Into the Black (Reuters) Reuters - Short-sellers, Wall Street's dwindling\band of ultra-cynics, are seeing green again.
#
# textattack: Last sample:
# Nets get Carter from Raptors INDIANAPOLIS -- All-Star Vince Carter was traded by the Toronto Raptors to the New Jersey Nets for Alonzo Mourning, Eric Williams, Aaron Williams, and a pair of first-round draft picks yesterday.
#
# textattack: Found 4 distinct outputs.
# textattack: Most common outputs:
# 	 2      (30000)
# 	 3      (30000)
# 	 1      (30000)
# 	 0      (30000)

# %% [markdown]
# The dataset looks good! It's lowercased already, so we'll make sure our model is uncased. The longest input is 178 words, so we can cap our maximum sequence length (`--model-max-length`) at 180.
#
# We'll train [`distilbert-base-uncased`](https://huggingface.co/transformers/model_doc/distilbert.html), since it's a relatively small model, and a good example of how we integrate with `transformers`.
#
# So we have our command:
#
# ```bash
# textattack train                      \ # Train a model with TextAttack
#     --model distilbert-base-uncased   \ # Using distilbert, uncased version, from `transformers`
#     --dataset rotten_tomatoes         \ # On the Rotten Tomatoes dataset
#     --model-num-labels 4              \ # That has 4 labels
#     --model-max-length 180             \ # With a maximum sequence length of 180
#     --per-device-train-batch-size 128 \ # And batch size of 128
#     --num-epochs 3                    \ # For 3 epochs
# ```
#
# Now let's run it (please remember to use GPU if you have access):

# %%
#ds = tfds.load('huggingface:yelp_review_full/yelp_review_full')
#distilroberta-base

# %%
# !textattack train --model-name-or-path distilbert-base-uncased --dataset ag_news --model-num-labels 4 --model-max-length 180 --per-device-train-batch-size 128 --num-epochs 3
# Out:
# 2023-12-17 15:56:31.379871: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 15:56:31.379936: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 15:56:31.379992: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 15:56:32.754164: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-17 15:56:35.795109: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# textattack: Loading transformers AutoModelForSequenceClassification: distilbert-base-uncased
# config.json: 100% 483/483 [00:00<00:00, 1.67MB/s]
# model.safetensors: 100% 268M/268M [00:01<00:00, 223MB/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json: 100% 28.0/28.0 [00:00<00:00, 109kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 1.43MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 1.92MB/s]
# textattack: Loading datasets dataset ag_news, split train.
# textattack: Loading datasets dataset ag_news, split test.
# textattack: Writing logs to ./outputs/2023-12-17-15-56-36-938484/train_log.txt.
# textattack: Wrote original training args to ./outputs/2023-12-17-15-56-36-938484/training_args.json.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# textattack: ***** Running training *****
# textattack:   Num examples = 120000
# textattack:   Num epochs = 3
# textattack:   Num clean epochs = 3
# textattack:   Instantaneous batch size per device = 128
# textattack:   Total train batch size (w. parallel, distributed & accumulation) = 128
# textattack:   Gradient accumulation steps = 1
# textattack:   Total optimization steps = 2814
# textattack: ==========================================================
# textattack: Epoch 1
# textattack: Running clean epoch 1/3
# Loss 0.33180: 100% 938/938 [27:28<00:00,  1.76s/it]
# textattack: Train accuracy: 88.80%
# textattack: Eval accuracy: 93.66%
# textattack: Best score found. Saved model to ./outputs/2023-12-17-15-56-36-938484/best_model/
# textattack: ==========================================================
# textattack: Epoch 2
# textattack: Running clean epoch 2/3
# Loss 0.23411: 100% 938/938 [27:34<00:00,  1.76s/it]
# textattack: Train accuracy: 95.38%
# textattack: Eval accuracy: 94.72%
# textattack: Best score found. Saved model to ./outputs/2023-12-17-15-56-36-938484/best_model/
# textattack: ==========================================================
# textattack: Epoch 3
# textattack: Running clean epoch 3/3
# Loss 0.18483: 100% 938/938 [27:35<00:00,  1.76s/it]
# textattack: Train accuracy: 97.15%
# textattack: Eval accuracy: 94.78%
# textattack: Best score found. Saved model to ./outputs/2023-12-17-15-56-36-938484/best_model/
# textattack: Wrote README to ./outputs/2023-12-17-15-56-36-938484/README.md.

# %% [markdown]
# ## Evaluation
#
# We successfully fine-tuned `distilbert-base-cased` for 3 epochs. Now let's evaluate it using `textattack eval`. This is as simple as providing the path to the pretrained model (that you just obtain from running the above command!) to `--model`, along with the number of evaluation samples. `textattack eval` will automatically load the evaluation data from training:

# %%
# !textattack eval --num-examples 100 --model ./outputs/2023-12-17-15-56-36-938484/best_model/ --dataset-from-huggingface ag_news --dataset-split test
# Out:
# 2023-12-17 21:53:37.872324: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 21:53:37.872372: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 21:53:37.872421: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 21:53:38.965688: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-17 21:53:41.714307: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# textattack: Loading datasets dataset ag_news, split test.
# textattack: Got 100 predictions.
# textattack: Correct 95/100 (95.00%)

# %% [markdown]
# Awesome -- we were able to train a model up to 94.20% accuracy on the test dataset – with only a single command!

# %% [markdown]
# ## Attack
#
# Finally, let's attack our pre-trained model.  We can do this by passing `--recipe clare` to `textattack attack`.
#
# > *Warning*: We're printing out 100 examples and, if the attack succeeds, their perturbations. The output of this command is going to be quite long!

# %%
# !textattack attack --help
# Out:
# 2023-12-17 18:15:06.960612: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 18:15:06.960668: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 18:15:06.960719: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 18:15:08.185269: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-17 18:15:11.495757: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# usage: [python -m] textattack <command> [<args>] attack [-h]
#                                                         [--model MODEL | --model-from-file MODEL_FROM_FILE | --model-from-huggingface MODEL_FROM_HUGGINGFACE]
#                                                         [--dataset-by-model DATASET_BY_MODEL | --dataset-from-huggingface DATASET_FROM_HUGGINGFACE | --dataset-from-file DATASET_FROM_FILE]
#                                                         [--dataset-split DATASET_SPLIT]
#                                                         [--filter-by-labels FILTER_BY_LABELS [FILTER_BY_LABELS ...]]
#                                                         [--transformation TRANSFORMATION]
#                                                         [--constraints [CONSTRAINTS ...]]
#                                                         [--goal-function GOAL_FUNCTION]
#                                                         [--search-method SEARCH_METHOD | --attack-recipe {alzantot,bae,bert-attack,faster-alzantot,deepwordbug,hotflip,input-reduction,kuleshov,morpheus,seq2sick,textbugger,textfooler,pwws,iga,pruthi,pso,checklist,clare,a2t} | --attack-from-file ATTACK_FROM_FILE]
#                                                         [--interactive]
#                                                         [--model-batch-size MODEL_BATCH_SIZE]
#                                                         [--model-cache-size MODEL_CACHE_SIZE]
#                                                         [--constraint-cache-size CONSTRAINT_CACHE_SIZE]
#                                                         [--num-examples NUM_EXAMPLES | --num-successful-examples NUM_SUCCESSFUL_EXAMPLES]
#                                                         [--num-examples-offset NUM_EXAMPLES_OFFSET]
#                                                         [--query-budget QUERY_BUDGET] [--shuffle]
#                                                         [--attack-n]
#                                                         [--checkpoint-dir CHECKPOINT_DIR]
#                                                         [--checkpoint-interval CHECKPOINT_INTERVAL]
#                                                         [--random-seed RANDOM_SEED] [--parallel]
#                                                         [--num-workers-per-device NUM_WORKERS_PER_DEVICE]
#                                                         [--log-to-txt [LOG_TO_TXT]]
#                                                         [--log-to-csv [LOG_TO_CSV]]
#                                                         [--log-summary-to-json [LOG_SUMMARY_TO_JSON]]
#                                                         [--csv-coloring-style CSV_COLORING_STYLE]
#                                                         [--log-to-visdom [LOG_TO_VISDOM]]
#                                                         [--log-to-wandb [LOG_TO_WANDB]]
#                                                         [--disable-stdout] [--silent]
#                                                         [--enable-advance-metrics]
#
# options:
#   -h, --help            show this help message and exit
#   --model MODEL         Name of or path to a pre-trained TextAttack model to load. Choices:
#                         ['bert-base-uncased', 'bert-base-uncased-ag-news', 'bert-base-uncased-
#                         cola', 'bert-base-uncased-imdb', 'bert-base-uncased-mnli', 'bert-base-
#                         uncased-mrpc', 'bert-base-uncased-qnli', 'bert-base-uncased-qqp', 'bert-
#                         base-uncased-rte', 'bert-base-uncased-sst2', 'bert-base-uncased-stsb',
#                         'bert-base-uncased-wnli', 'bert-base-uncased-mr', 'bert-base-uncased-
#                         snli', 'bert-base-uncased-yelp', 'distilbert-base-uncased', 'distilbert-
#                         base-cased-cola', 'distilbert-base-cased-mrpc', 'distilbert-base-cased-
#                         qqp', 'distilbert-base-cased-snli', 'distilbert-base-cased-sst2',
#                         'distilbert-base-cased-stsb', 'distilbert-base-uncased-ag-news',
#                         'distilbert-base-uncased-cola', 'distilbert-base-uncased-imdb',
#                         'distilbert-base-uncased-mnli', 'distilbert-base-uncased-mr', 'distilbert-
#                         base-uncased-mrpc', 'distilbert-base-uncased-qnli', 'distilbert-base-
#                         uncased-rte', 'distilbert-base-uncased-wnli', 'roberta-base', 'roberta-
#                         base-ag-news', 'roberta-base-cola', 'roberta-base-imdb', 'roberta-base-
#                         mr', 'roberta-base-mrpc', 'roberta-base-qnli', 'roberta-base-rte',
#                         'roberta-base-sst2', 'roberta-base-stsb', 'roberta-base-wnli', 'albert-
#                         base-v2', 'albert-base-v2-ag-news', 'albert-base-v2-cola', 'albert-
#                         base-v2-imdb', 'albert-base-v2-mr', 'albert-base-v2-rte', 'albert-
#                         base-v2-qqp', 'albert-base-v2-snli', 'albert-base-v2-sst2', 'albert-
#                         base-v2-stsb', 'albert-base-v2-wnli', 'albert-base-v2-yelp', 'xlnet-base-
#                         cased', 'xlnet-base-cased-cola', 'xlnet-base-cased-imdb', 'xlnet-base-
#                         cased-mr', 'xlnet-base-cased-mrpc', 'xlnet-base-cased-rte', 'xlnet-base-
#                         cased-stsb', 'xlnet-base-cased-wnli', 'lstm-ag-news', 'lstm-imdb', 'lstm-
#                         mr', 'lstm-sst2', 'lstm-yelp', 'cnn-ag-news', 'cnn-imdb', 'cnn-mr', 'cnn-
#                         sst2', 'cnn-yelp', 't5-en-de', 't5-en-fr', 't5-en-ro', 't5-summarization']
#                         (default: None)
#   --model-from-file MODEL_FROM_FILE
#                         File of model and tokenizer to import. (default: None)
#   --model-from-huggingface MODEL_FROM_HUGGINGFACE
#                         Name of or path of pre-trained HuggingFace model to load. (default: None)
#   --dataset-by-model DATASET_BY_MODEL
#                         Dataset to load depending on the name of the model (default: None)
#   --dataset-from-huggingface DATASET_FROM_HUGGINGFACE
#                         Dataset to load from `datasets` repository. (default: None)
#   --dataset-from-file DATASET_FROM_FILE
#                         Dataset to load from a file. (default: None)
#   --dataset-split DATASET_SPLIT
#                         Split of dataset to use when specifying --dataset-by-model or --dataset-
#                         from-huggingface. (default: None)
#   --filter-by-labels FILTER_BY_LABELS [FILTER_BY_LABELS ...]
#                         List of labels to keep in the dataset and discard all others. (default:
#                         None)
#   --transformation TRANSFORMATION
#                         The transformation to apply. Usage: "--transformation
#                         {transformation}:{arg_1}={value_1},{arg_3}={value_3}". Choices: {'word-
#                         swap-qwerty', 'word-swap-gradient', 'word-swap-embedding', 'word-
#                         deletion', 'word-swap-random-char-substitution', 'random-synonym-
#                         insertion', 'word-swap-homoglyph', 'word-swap-neighboring-char-swap',
#                         'word-swap-wordnet', 'word-swap-masked-lm', 'word-swap-random-char-
#                         deletion', 'word-swap-inflections', 'word-swap-random-char-insertion',
#                         'word-swap-hownet'} (default: word-swap-embedding)
#   --constraints [CONSTRAINTS ...]
#                         Constraints to add to the attack. Usage: "--constraints
#                         {constraint}:{arg_1}={value_1},{arg_3}={value_3}". Choices:
#                         dict_keys(['embedding', 'bert', 'infer-sent', 'thought-vector', 'use',
#                         'muse', 'bert-score', 'lang-tool', 'part-of-speech', 'goog-lm', 'gpt2',
#                         'learning-to-write', 'cola', 'bleu', 'chrf', 'edit-distance', 'meteor',
#                         'max-words-perturbed', 'repeat', 'stopword', 'max-word-index']) (default:
#                         ['repeat', 'stopword'])
#   --goal-function GOAL_FUNCTION, -g GOAL_FUNCTION
#                         The goal function to use. choices: hardlabel-classification, targeted-
#                         classification, untargeted-classification, input-reduction, minimize-bleu,
#                         non-overlapping-output, text-to-text (default: untargeted-classification)
#   --search-method SEARCH_METHOD, --search SEARCH_METHOD, -s SEARCH_METHOD
#                         The search method to use. choices: beam-search, greedy, ga-word, greedy-
#                         word-wir, pso (default: greedy-word-wir)
#   --attack-recipe {alzantot,bae,bert-attack,faster-alzantot,deepwordbug,hotflip,input-reduction,kuleshov,morpheus,seq2sick,textbugger,textfooler,pwws,iga,pruthi,pso,checklist,clare,a2t}, --recipe {alzantot,bae,bert-attack,faster-alzantot,deepwordbug,hotflip,input-reduction,kuleshov,morpheus,seq2sick,textbugger,textfooler,pwws,iga,pruthi,pso,checklist,clare,a2t}, -r {alzantot,bae,bert-attack,faster-alzantot,deepwordbug,hotflip,input-reduction,kuleshov,morpheus,seq2sick,textbugger,textfooler,pwws,iga,pruthi,pso,checklist,clare,a2t}
#                         full attack recipe (overrides provided goal function, transformation &
#                         constraints) (default: None)
#   --attack-from-file ATTACK_FROM_FILE
#                         Path of `.py` file from which to load attack from. Use
#                         `<path>^<variable_name>` to specifiy which variable to import from the
#                         file. (default: None)
#   --interactive         Whether to run attacks interactively. (default: False)
#   --model-batch-size MODEL_BATCH_SIZE
#                         The batch size for making calls to the model. (default: 32)
#   --model-cache-size MODEL_CACHE_SIZE
#                         The maximum number of items to keep in the model results cache at once.
#                         (default: 262144)
#   --constraint-cache-size CONSTRAINT_CACHE_SIZE
#                         The maximum number of items to keep in the constraints cache at once.
#                         (default: 262144)
#   --num-examples NUM_EXAMPLES, -n NUM_EXAMPLES
#                         The number of examples to process, -1 for entire dataset. (default: 10)
#   --num-successful-examples NUM_SUCCESSFUL_EXAMPLES
#                         The number of successful adversarial examples we want. (default: None)
#   --num-examples-offset NUM_EXAMPLES_OFFSET, -o NUM_EXAMPLES_OFFSET
#                         The offset to start at in the dataset. (default: 0)
#   --query-budget QUERY_BUDGET, -q QUERY_BUDGET
#                         The maximum number of model queries allowed per example attacked. Setting
#                         this overwrites the query budget set in `GoalFunction` object. (default:
#                         None)
#   --shuffle             If `True`, shuffle the samples before we attack the dataset. Default is
#                         False. (default: False)
#   --attack-n            Whether to run attack until `n` examples have been attacked (not skipped).
#                         (default: False)
#   --checkpoint-dir CHECKPOINT_DIR
#                         The directory to save checkpoint files. (default: checkpoints)
#   --checkpoint-interval CHECKPOINT_INTERVAL
#                         If set, checkpoint will be saved after attacking every N examples. If not
#                         set, no checkpoints will be saved. (default: None)
#   --random-seed RANDOM_SEED
#                         Random seed for reproducibility. (default: 765)
#   --parallel            Run attack using multiple GPUs. (default: False)
#   --num-workers-per-device NUM_WORKERS_PER_DEVICE
#                         Number of worker processes to run per device. (default: 1)
#   --log-to-txt [LOG_TO_TXT]
#                         Path to which to save attack logs as a text file. Set this argument if you
#                         want to save text logs. If the last part of the path ends with `.txt`
#                         extension, the path is assumed to path for output file. (default: None)
#   --log-to-csv [LOG_TO_CSV]
#                         Path to which to save attack logs as a CSV file. Set this argument if you
#                         want to save CSV logs. If the last part of the path ends with `.csv`
#                         extension, the path is assumed to path for output file. (default: None)
#   --log-summary-to-json [LOG_SUMMARY_TO_JSON]
#                         Path to which to save attack summary as a JSON file. Set this argument if
#                         you want to save attack results summary in a JSON. If the last part of the
#                         path ends with `.json` extension, the path is assumed to path for output
#                         file. (default: None)
#   --csv-coloring-style CSV_COLORING_STYLE
#                         Method for choosing how to mark perturbed parts of the text in CSV logs.
#                         Options are "file" and "plain". "file" wraps text with double brackets `[[
#                         <text> ]]` while "plain" does not mark any text. Default is "file".
#                         (default: file)
#   --log-to-visdom [LOG_TO_VISDOM]
#                         Set this argument if you want to log attacks to Visdom. The dictionary
#                         should have the following three keys and their corresponding values:
#                         `"env", "port", "hostname"`. Example for command line use: `--log-to-
#                         visdom {"env": "main", "port": 8097, "hostname": "localhost"}`. (default:
#                         None)
#   --log-to-wandb [LOG_TO_WANDB]
#                         Set this argument if you want to log attacks to WandB. The dictionary
#                         should have the following key and its corresponding value: `"project"`.
#                         Example for command line use: `--log-to-wandb {"project": "textattack"}`.
#                         (default: None)
#   --disable-stdout      Disable logging attack results to stdout (default: False)
#   --silent              Disable all logging (default: False)
#   --enable-advance-metrics
#                         Enable calculation and display of optional advance post-hoc metrics like
#                         perplexity, USE distance, etc. (default: False)

# %%
# !textattack attack --recipe clare --num-examples 100 --model ./outputs/2023-12-17-15-56-36-938484/best_model/ --dataset-from-huggingface ag_news --dataset-split test --query-budget 5000   --enable-advance-metrics
# Out:
# 2023-12-17 19:56:46.426617: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 19:56:46.426669: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 19:56:46.426724: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 19:56:47.543735: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-17 19:56:50.288145: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# textattack: Loading datasets dataset ag_news, split test.
# If you want to use `RobertaLMHeadModel` as a standalone, add `is_decoder=True.`
# textattack: Unknown if model of class <class 'transformers.models.distilbert.modeling_distilbert.DistilBertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack(
#   (search_method): GreedySearch
#   (goal_function):  UntargetedClassification
#   (transformation):  CompositeTransformation(
#     (0): WordSwapMaskedLM(
#         (method):  bae
#         (masked_lm_name):  RobertaForCausalLM
#         (max_length):  512
#         (max_candidates):  50
#         (min_confidence):  0.0005
#       )
#     (1): WordInsertionMaskedLM(
#         (masked_lm_name):  RobertaForCausalLM
#         (max_length):  512
#         (max_candidates):  50
#         (min_confidence):  0.0
#       )
#     (2): WordMergeMaskedLM(
#         (masked_lm_name):  RobertaForCausalLM
#         (max_length):  512
#         (max_candidates):  50
#         (min_confidence):  0.005
#       )
#     )
#   (constraints):
#     (0): UniversalSentenceEncoder(
#         (metric):  cosine
#         (threshold):  0.7
#         (window_size):  15
#         (skip_text_shorter_than_window):  True
#         (compare_against_original):  True
#       )
#     (1): RepeatModification
#     (2): StopwordModification
#   (is_black_box):  True
# )
#
#   0% 0/100 [00:00<?, ?it/s]2023-12-17 19:57:05,772 SequenceTagger predicts: Dictionary with 19 tags: <unk>, NOUN, VERB, PUNCT, ADP, DET, PROPN, PRON, ADJ, ADV, CCONJ, PART, NUM, AUX, INTJ, SYM, X, <START>, <STOP>
#   1% 1/100 [00:40<1:06:42, 40.43s/it]--------------------------------------------- Result 1 ---------------------------------------------
# Business (100%) --> Sci/tech (83%)
#
# Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
#
# Fears for T N pension after talks </s> Unions representing IT workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 0 / 0 / 1:   2% 2/100 [01:44<1:25:16, 52.20s/it]--------------------------------------------- Result 2 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 1 / 0 / 2:   3% 3/100 [02:38<1:25:31, 52.90s/it]--------------------------------------------- Result 3 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 2 / 0 / 3:   4% 4/100 [03:25<1:22:06, 51.32s/it]--------------------------------------------- Result 4 ---------------------------------------------
# Sci/tech (100%) --> Sports (100%)
#
# Prediction Unit Helps Forecast Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
#
# Prediction Unit Helps NFL (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 2 / 0 / 4:   5% 5/100 [04:16<1:21:07, 51.24s/it]--------------------------------------------- Result 5 ---------------------------------------------
# Sci/tech (99%) --> World (80%)
#
# Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
#
# Calif. Aims to Limit Farm-Related Smog (AFP) AFP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 2 / 0 / 5:   5% 5/100 [04:16<1:21:07, 51.24s/it]2023-12-17 20:02:06.362766: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 761725440 exceeds 10% of free system memory.
# [Succeeded / Failed / Skipped / Total] 3 / 2 / 0 / 5:   6% 6/100 [05:40<1:28:53, 56.74s/it]--------------------------------------------- Result 6 ---------------------------------------------
# Sci/tech (99%) --> [FAILED]
#
# Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 3 / 0 / 6:   6% 6/100 [05:40<1:28:53, 56.74s/it]2023-12-17 20:03:20.683544: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 595717120 exceeds 10% of free system memory.
# [Succeeded / Failed / Skipped / Total] 3 / 3 / 0 / 6:   7% 7/100 [06:53<1:31:32, 59.06s/it]--------------------------------------------- Result 7 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 4 / 0 / 7:   7% 7/100 [06:53<1:31:32, 59.06s/it]2023-12-17 20:04:38.828478: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 691653120 exceeds 10% of free system memory.
# [Succeeded / Failed / Skipped / Total] 3 / 4 / 0 / 7:   8% 8/100 [08:12<1:34:19, 61.51s/it]--------------------------------------------- Result 8 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 5 / 0 / 8:   9% 9/100 [08:38<1:27:20, 57.59s/it]--------------------------------------------- Result 9 ---------------------------------------------
# Sci/tech (99%) --> World (98%)
#
# E-mail scam targets police chief Wiltshire Police warns about "phishing" after its fraud squad chief was targeted.
#
# E-mail scam targets police chief Islamabad Police warns about "unity" after its fraud squad chief was targeted.
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 5 / 0 / 9:  10% 10/100 [09:02<1:21:18, 54.21s/it]--------------------------------------------- Result 10 ---------------------------------------------
# Sci/tech (87%) --> Business (98%)
#
# Card fraud unit nets 36,000 cards In its first two years, the UK's dedicated card fraud unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
#
# Card fraud unit nets 36,000 cards In its first two years, the UK's dedicated card fraud unit, Barclays has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
#
#
# [Succeeded / Failed / Skipped / Total] 5 / 5 / 0 / 10:  11% 11/100 [10:11<1:22:25, 55.56s/it]--------------------------------------------- Result 11 ---------------------------------------------
# Sci/tech (98%) --> [FAILED]
#
# Group to Propose New High-Speed Wireless Format  LOS ANGELES (Reuters) - A group of technology companies  including Texas Instruments Inc. &lt;TXN.N&gt;, STMicroelectronics  &lt;STM.PA&gt; and Broadcom Corp. &lt;BRCM.O&gt;, on Thursday said they  will propose a new wireless networking standard up to 10 times  the speed of the current generation.
#
#
# [Succeeded / Failed / Skipped / Total] 5 / 6 / 0 / 11:  12% 12/100 [11:12<1:22:10, 56.03s/it]--------------------------------------------- Result 12 ---------------------------------------------
# Sci/tech (98%) --> [FAILED]
#
# Apple Launches Graphics Software, Video Bundle  LOS ANGELES (Reuters) - Apple Computer Inc.&lt;AAPL.O&gt; on  Tuesday began shipping a new program designed to let users  create real-time motion graphics and unveiled a discount  video-editing software bundle featuring its flagship Final Cut  Pro software.
#
#
# [Succeeded / Failed / Skipped / Total] 5 / 7 / 0 / 12:  13% 13/100 [12:08<1:21:14, 56.03s/it]--------------------------------------------- Result 13 ---------------------------------------------
# Sci/tech (99%) --> [FAILED]
#
# Dutch Retailer Beats Apple to Local Download Market  AMSTERDAM (Reuters) - Free Record Shop, a Dutch music  retail chain, beat Apple Computer Inc. to market on Tuesday  with the launch of a new download service in Europe's latest  battleground for digital song services.
#
#
# [Succeeded / Failed / Skipped / Total] 5 / 8 / 0 / 13:  14% 14/100 [13:01<1:19:58, 55.79s/it]--------------------------------------------- Result 14 ---------------------------------------------
# Sci/tech (95%) --> World (75%)
#
# Super ant colony hits Australia A giant 100km colony of ants  which has been discovered in Melbourne, Australia, could threaten local insect species.
#
# Super ant plague hits Australia A giant 100km colony of cricket  has been discovered in Melbourne, Australia, could threaten local cricket species.
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 8 / 0 / 14:  15% 15/100 [13:27<1:16:17, 53.86s/it]--------------------------------------------- Result 15 ---------------------------------------------
# Sci/tech (86%) --> World (86%)
#
# Socialites unite dolphin groups Dolphin groups, or "pods", rely on socialites to keep them from collapsing, scientists claim.
#
# Socialites unite labour groups Dolphin groups, or "pods", rely on socialites to keep them from collapsing, organisers claim.
#
#
# [Succeeded / Failed / Skipped / Total] 7 / 8 / 0 / 15:  16% 16/100 [13:43<1:12:02, 51.46s/it]--------------------------------------------- Result 16 ---------------------------------------------
# Sci/tech (78%) --> World (64%)
#
# Teenage T. rex's monster growth Tyrannosaurus rex achieved its massive size due to an enormous growth spurt during its adolescent years.
#
# Teenage T. rex's monster growth Freddy rex achieved its massive size due to an enormous growth spurt during its adolescent years.
#
#
# [Succeeded / Failed / Skipped / Total] 8 / 8 / 0 / 16:  17% 17/100 [14:38<1:11:31, 51.70s/it]--------------------------------------------- Result 17 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# Scientists Discover Ganymede has a Lumpy Interior Jet Propulsion Lab -- Scientists have discovered irregular lumps beneath the icy surface of Jupiter's largest moon, Ganymede. These irregular masses may be rock formations, supported by Ganymede's icy shell for billions of years...
#
#
# [Succeeded / Failed / Skipped / Total] 8 / 9 / 0 / 17:  18% 18/100 [15:43<1:11:37, 52.40s/it]--------------------------------------------- Result 18 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# Mars Rovers Relay Images Through Mars Express European Space Agency -- ESAs Mars Express has relayed pictures from one of NASA's Mars rovers for the first time, as part of a set of interplanetary networking demonstrations.     The demonstrations pave the way for future Mars missions to draw on joint interplanetary networking capabilities...
#
#
# [Succeeded / Failed / Skipped / Total] 8 / 10 / 0 / 18:  19% 19/100 [16:40<1:11:07, 52.68s/it]--------------------------------------------- Result 19 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# Rocking the Cradle of Life When did life begin? One evidential clue stems from the fossil records in Western Australia, although whether these layered sediments are biological or chemical has spawned a spirited debate. Oxford researcher, Nicola McLoughlin, describes some of the issues in contention.
#
#
# [Succeeded / Failed / Skipped / Total] 8 / 11 / 0 / 19:  20% 20/100 [17:18<1:09:13, 51.91s/it]--------------------------------------------- Result 20 ---------------------------------------------
# Sci/tech (99%) --> Business (64%)
#
# Storage, servers bruise HP earnings update Earnings per share rise compared with a year ago, but company misses analysts' expectations by a long shot.
#
# Storage, headline bruise and earnings update Earnings per share rise compared with a year ago, but company misses analysts' expectations by a long shot.
#
#
# [Succeeded / Failed / Skipped / Total] 9 / 11 / 0 / 20:  20% 20/100 [17:18<1:09:13, 51.91s/it]--------------------------------------------- Result 21 ---------------------------------------------
# Business (62%) --> [38:5:240m[SKIPPED]
#
# IBM to hire even more new workers By the end of the year, the computing giant plans to have its biggest headcount since 1991.
#
#
# [Succeeded / Failed / Skipped / Total] 9 / 11 / 1 / 21:  22% 22/100 [18:24<1:05:17, 50.22s/it]--------------------------------------------- Result 22 ---------------------------------------------
# Sci/tech (93%) --> [FAILED]
#
# Sun's Looking Glass Provides 3D View Developers get early code for new operating system 'skin' still being crafted.
#
#
# [Succeeded / Failed / Skipped / Total] 9 / 12 / 1 / 22:  23% 23/100 [18:54<1:03:19, 49.34s/it]--------------------------------------------- Result 23 ---------------------------------------------
# Sci/tech (98%) --> World (59%)
#
# IBM Chips May Someday Heal Themselves New technology applies electrical fuses to help identify and repair faults.
#
# Brain Chips May Someday Heal Themselves New MRI applies electrical fuses to help identify and repair faults.
#
#
# [Succeeded / Failed / Skipped / Total] 10 / 12 / 1 / 23:  23% 23/100 [18:54<1:03:19, 49.34s/it]--------------------------------------------- Result 24 ---------------------------------------------
# Business (94%) --> [38:5:240m[SKIPPED]
#
# Some People Not Eligible to Get in on Google IPO Google has billed its IPO as a way for everyday people to get in on the process, denying Wall Street the usual stranglehold it's had on IPOs. Public bidding, a minimum of just five shares, an open process with 28 underwriters - all this pointed to a new level of public participation. But this isn't the case.
#
#
# [Succeeded / Failed / Skipped / Total] 10 / 12 / 2 / 24:  25% 25/100 [19:25<58:16, 46.62s/it]--------------------------------------------- Result 25 ---------------------------------------------
# Sci/tech (97%) --> Business (98%)
#
# Rivals Try to Turn Tables on Charles Schwab By MICHAEL LIEDTKE     SAN FRANCISCO (AP) -- With its low prices and iconoclastic attitude, discount stock broker Charles Schwab Corp. (SCH) represented an annoying stone in Wall Street's wing-tipped shoes for decades...
#
# Rivals Try to Turn Tables on Charles Schwab By MICHAEL LIEDTKE     SAN FRANCISCO (Bloomberg) -- With its low prices and iconoclastic attitude, discount stock broker Charles Schwab Corp. (SCH) represented an annoying stone in Wall Street's wing-tipped shoes for decades...
#
#
# [Succeeded / Failed / Skipped / Total] 11 / 12 / 2 / 25:  26% 26/100 [20:18<57:47, 46.86s/it]--------------------------------------------- Result 26 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# News: Sluggish movement on power grid cyber security Industry cyber security standards fail to reach some of the most vulnerable components of the power grid.\
#
#
# [Succeeded / Failed / Skipped / Total] 11 / 13 / 2 / 26:  27% 27/100 [21:02<56:52, 46.74s/it]--------------------------------------------- Result 27 ---------------------------------------------
# Sports (95%) --> World (75%)
#
# Giddy Phelps Touches Gold for First Time Michael Phelps won the gold medal in the 400 individual medley and set a world record in a time of 4 minutes 8.26 seconds.
#
# Michael Phelps Touches Gold for First Time Michael Phelps won the gold medal in the 400 meter and set a world record in a time of 4 minutes 8.26 seconds.
#
#
# [Succeeded / Failed / Skipped / Total] 12 / 13 / 2 / 27:  28% 28/100 [22:13<57:09, 47.63s/it]--------------------------------------------- Result 28 ---------------------------------------------
# Sports (100%) --> Sci/tech (55%)
#
# Tougher rules won't soften Law's game FOXBOROUGH -- Looking at his ridiculously developed upper body, with huge biceps and hardly an ounce of fat, it's easy to see why Ty Law, arguably the best cornerback in football, chooses physical play over finesse. That's not to imply that he's lacking a finesse component, because he can shut down his side of the field much as Deion Sanders ...
#
# Online protection rules won't soften Law's game FOXBOROUGH -- Looking at his ridiculously developed upper body, with huge biceps and hardly an ounce of fat, it's easy to see why Ty Law, arguably the best cornerback in football, chooses physical play over finesse. That's not to imply that he's lacking a finesse component, because he can shut down his side of the field much as Deion Sanders ...
#
#
# [Succeeded / Failed / Skipped / Total] 13 / 13 / 2 / 28:  29% 29/100 [23:29<57:31, 48.61s/it]--------------------------------------------- Result 29 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Shoppach doesn't appear ready to hit the next level With the weeks dwindling until Jason Varitek enters free agency, the Red Sox continue to carefully monitor Kelly Shoppach , their catcher of the future, in his climb toward the majors. The Sox like most of what they have seen at Triple A Pawtucket from Shoppach, though it remains highly uncertain whether he can make the adjustments at the plate ...
#
#
# [Succeeded / Failed / Skipped / Total] 13 / 14 / 2 / 29:  30% 30/100 [24:46<57:49, 49.56s/it]--------------------------------------------- Result 30 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Mighty Ortiz makes sure Sox can rest easy Just imagine what David Ortiz could do on a good night's rest. Ortiz spent the night before last with his baby boy, D'Angelo, who is barely 1 month old. He had planned on attending the Red Sox' Family Day at Fenway Park yesterday morning, but he had to sleep in. After all, Ortiz had a son at home, and he ...
#
#
# [Succeeded / Failed / Skipped / Total] 13 / 15 / 2 / 30:  31% 31/100 [25:36<57:00, 49.57s/it]--------------------------------------------- Result 31 ---------------------------------------------
# Sports (100%) --> Business (72%)
#
# They've caught his eye In  quot;helping themselves, quot; Ricky Bryant, Chas Gessner, Michael Jennings, and David Patten did nothing Friday night to make Bill Belichick's decision on what to do with his receivers any easier.
#
# They've caught his eye In  quot;helping themselves, quot; Ricky Sherman, Chas Gessner, Michael Jennings, and David Patten did nothing Friday night to make Bill Belichick's decision on what to do with his money any easier.
#
#
# [Succeeded / Failed / Skipped / Total] 14 / 15 / 2 / 31:  32% 32/100 [26:34<56:28, 49.83s/it]--------------------------------------------- Result 32 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Indians Mount Charge The Cleveland Indians pulled within one game of the AL Central lead by beating the Minnesota Twins, 7-1, Saturday night with home runs by Travis Hafner and Victor Martinez.
#
#
# [Succeeded / Failed / Skipped / Total] 14 / 16 / 2 / 32:  33% 33/100 [27:29<55:49, 49.99s/it]--------------------------------------------- Result 33 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Sister of man who died in Vancouver police custody slams chief (Canadian Press) Canadian Press - VANCOUVER (CP) - The sister of a man who died after a violent confrontation with police has demanded the city's chief constable resign for defending the officer involved.
#
#
# [Succeeded / Failed / Skipped / Total] 14 / 17 / 2 / 33:  34% 34/100 [28:04<54:29, 49.53s/it]--------------------------------------------- Result 34 ---------------------------------------------
# World (100%) --> Sports (99%)
#
# Man Sought  #36;50M From McGreevey, Aides Say (AP) AP - The man who claims Gov. James E. McGreevey sexually harassed him was pushing for a cash settlement of up to  #36;50 million before the governor decided to announce that he was gay and had an extramarital affair, sources told The Associated Press.
#
# Man Sought  #36;50M From McGreevey, Aides Say (AP) AP - The Syracuse man who claims Gov. James E. McGreevey sexually harassed him was pushing for a cash settlement of up to  #36;50 million before the governor decided to announce that he was gay and had an extramarital affair, sources told The Associated Press.
#
#
# [Succeeded / Failed / Skipped / Total] 15 / 17 / 2 / 34:  35% 35/100 [29:06<54:03, 49.90s/it]--------------------------------------------- Result 35 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Explosions Echo Throughout Najaf NAJAF, Iraq - Explosions and gunfire rattled through the city of Najaf as U.S. troops in armored vehicles and tanks rolled back into the streets here Sunday, a day after the collapse of talks - and with them a temporary cease-fire - intended to end the fighting in this holy city...
#
#
# [Succeeded / Failed / Skipped / Total] 15 / 18 / 2 / 35:  36% 36/100 [30:18<53:53, 50.52s/it]--------------------------------------------- Result 36 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Frail Pope Celebrates Mass at Lourdes LOURDES, France - A frail Pope John Paul II, breathing heavily and gasping at times, celebrated an open-air Mass on Sunday for several hundred thousand pilgrims, many in wheelchairs, at a shrine to the Virgin Mary that is associated with miraculous cures.    At one point he said "help me" in Polish while struggling through his homily in French...
#
#
# [Succeeded / Failed / Skipped / Total] 15 / 19 / 2 / 36:  36% 36/100 [30:18<53:53, 50.52s/it]--------------------------------------------- Result 37 ---------------------------------------------
# Business (62%) --> [38:5:240m[SKIPPED]
#
# Venezuela Prepares for Chavez Recall Vote Supporters and rivals warn of possible fraud; government says Chavez's defeat could produce turmoil in world oil market.
#
#
# [Succeeded / Failed / Skipped / Total] 15 / 19 / 3 / 37:  38% 38/100 [30:47<50:14, 48.62s/it]--------------------------------------------- Result 38 ---------------------------------------------
# World (100%) --> Sci/tech (57%)
#
# 1994 Law Designed to Preserve Guard Jobs (AP) AP - A 1994 law strengthened job protections for National Guard and Reserve troops called to active duty. Here are major provisions of the Uniformed Services Employment and Reemployment Rights Act (USERRA).
#
# 1994 Law Designed to Preserve Guard Jobs (AP) AP - A 1994 law strengthened job protections for National Space Guard and Reserve troops called to active duty. Here are major provisions of the Uniformed Services Employment and Reemployment Rights Act (USERRA).
#
#
# [Succeeded / Failed / Skipped / Total] 16 / 19 / 3 / 38:  39% 39/100 [31:59<50:02, 49.23s/it]--------------------------------------------- Result 39 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Iran Warns Its Missiles Can Hit Anywhere in Israel  TEHRAN (Reuters) - A senior Iranian military official said  Sunday Israel and the United States would not dare attack Iran  since it could strike back anywhere in Israel with its latest  missiles, news agencies reported.
#
#
# [Succeeded / Failed / Skipped / Total] 16 / 20 / 3 / 39:  40% 40/100 [32:59<49:29, 49.50s/it]--------------------------------------------- Result 40 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Afghan Army Dispatched to Calm Violence KABUL, Afghanistan - Government troops intervened in Afghanistan's latest outbreak of deadly fighting between warlords, flying from the capital to the far west on U.S. and NATO airplanes to retake an air base contested in the violence, officials said Sunday...
#
#
# [Succeeded / Failed / Skipped / Total] 16 / 21 / 3 / 40:  41% 41/100 [34:05<49:03, 49.89s/it]--------------------------------------------- Result 41 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Johnson Helps D-Backs End Nine-Game Slide (AP) AP - Randy Johnson took a four-hitter into the ninth inning to help the Arizona Diamondbacks end a nine-game losing streak Sunday, beating Steve Trachsel and the New York Mets 2-0.
#
#
# [Succeeded / Failed / Skipped / Total] 16 / 22 / 3 / 41:  42% 42/100 [34:38<47:50, 49.49s/it]--------------------------------------------- Result 42 ---------------------------------------------
# Business (99%) --> Sci/tech (81%)
#
# Retailers Vie for Back-To-School Buyers (Reuters) Reuters - Apparel retailers are hoping their\back-to-school fashions will make the grade among\style-conscious teens and young adults this fall, but it could\be a tough sell, with students and parents keeping a tighter\hold on their wallets.
#
# Retailers Vie for Back-To-School Buyers (Reuters) Reuters - Online retailers are hoping their\back-to-school fashions will make the grade among\style-conscious teens and young adults this fall, but it could\be a tough sell, with students and parents keeping a tighter\hold on their wallets.
#
#
# [Succeeded / Failed / Skipped / Total] 17 / 22 / 3 / 42:  43% 43/100 [35:39<47:15, 49.75s/it]--------------------------------------------- Result 43 ---------------------------------------------
# World (100%) --> Sci/tech (94%)
#
# Politics an Afterthought Amid Hurricane (AP) AP - If Hurricane Charley had struck three years ago, President Bush's tour through the wreckage of this coastal city would have been just the sort of post-disaster visit that other presidents have made to the scenes of storms, earthquakes, floods and fires.
#
# Politics an Interactive Afterthought Amid Hurricane (AP) AP - FILE If Hurricane Charley had struck three years ago, President Bush's tour through the wreckage of this coastal city would have been just the sort of post-disaster visit that other presidents have made to the scenes of storms, earthquakes, floods and fires.
#
#
# [Succeeded / Failed / Skipped / Total] 18 / 22 / 3 / 43:  44% 44/100 [36:42<46:43, 50.06s/it]--------------------------------------------- Result 44 ---------------------------------------------
# Sci/tech (99%) --> [FAILED]
#
# Spam suspension hits Sohu.com shares (FT.com) FT.com - Shares in Sohu.com, a leading US-listed Chinese internet portal, fell more than 10 per cent on Friday after China's biggest mobile phone network operator imposed a one-year suspension on its multimedia messaging services because of customers being sent spam.
#
#
# [Succeeded / Failed / Skipped / Total] 18 / 23 / 3 / 44:  45% 45/100 [37:46<46:10, 50.37s/it]--------------------------------------------- Result 45 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Erstad's Double Lifts Angels to Win (AP) AP - Darin Erstad doubled in the go-ahead run in the eighth inning, lifting the Anaheim Angels to a 3-2 victory over the Detroit Tigers on Sunday. The win pulled Anaheim within a percentage point of Boston and Texas in the AL wild-card race.
#
#
# [Succeeded / Failed / Skipped / Total] 18 / 24 / 3 / 45:  46% 46/100 [38:42<45:26, 50.48s/it]--------------------------------------------- Result 46 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Drew Out of Braves' Lineup After Injury (AP) AP - Outfielder J.D. Drew missed the Atlanta Braves' game against the St. Louis Cardinals on Sunday night with a sore right quadriceps.
#
#
# [Succeeded / Failed / Skipped / Total] 18 / 25 / 3 / 46:  47% 47/100 [39:30<44:33, 50.44s/it]--------------------------------------------- Result 47 ---------------------------------------------
# World (99%) --> Sci/tech (66%)
#
# Venezuelans Flood Polls, Voting Extended  CARACAS, Venezuela (Reuters) - Venezuelans voted in huge  numbers on Sunday in a historic referendum on whether to recall  left-wing President Hugo Chavez and electoral authorities  prolonged voting well into the night.
#
# Venezuelans Flood Internet, Voting Extended  CARACAS, Venezuela (Reuters) - Venezuelans voted online in huge  numbers on Sunday in a historic referendum on whether to recall  left-wing President Hugo Chavez and electoral authorities  prolonged voting well into the night.
#
#
# [Succeeded / Failed / Skipped / Total] 19 / 25 / 3 / 47:  47% 47/100 [39:30<44:33, 50.44s/it]--------------------------------------------- Result 48 ---------------------------------------------
# Business (58%) --> [38:5:240m[SKIPPED]
#
# Dell Exits Low-End China Consumer PC Market  HONG KONG (Reuters) - Dell Inc. &lt;DELL.O&gt;, the world's  largest PC maker, said on Monday it has left the low-end  consumer PC market in China and cut its overall growth target  for the country this year due to stiff competition in the  segment.
#
#
# [Succeeded / Failed / Skipped / Total] 19 / 25 / 4 / 48:  49% 49/100 [39:55<41:32, 48.88s/it]--------------------------------------------- Result 49 ---------------------------------------------
# World (100%) --> Sci/tech (95%)
#
# China Says Taiwan Spy Also Operated in U.S. - Media  BEIJING (Reuters) - Beijing on Monday accused a  Chinese-American arrested for spying for Taiwan of building an  espionage network in the United States, and said he could go on  trial very soon.
#
# Apple Says Taiwan Spy Also Operated in U.S. - Media  BEIJING (Reuters) - Beijing on Monday accused a  Chinese-American arrested for spying for Taiwan of building an  espionage network in the United States, and said he could go on  trial very soon.
#
#
# [Succeeded / Failed / Skipped / Total] 20 / 25 / 4 / 49:  50% 50/100 [40:38<40:38, 48.76s/it]--------------------------------------------- Result 50 ---------------------------------------------
# Sports (100%) --> Business (98%)
#
# Another Major Non-Factor Another major, another disappointment for Tiger Woods, the No. 1 ranked player in the world who has not won a major championship since his triumph at the 2002 U.S. Open.
#
# Another Major Non-Factor Insurance major, another disappointment for Tiger Woods, the No. 1 ranked player in the investing world who has not won a major championship since his triumph at the 2002 U.S. Open.
#
#
# [Succeeded / Failed / Skipped / Total] 21 / 25 / 4 / 50:  51% 51/100 [41:35<39:57, 48.93s/it]--------------------------------------------- Result 51 ---------------------------------------------
# World (100%) --> [FAILED]
#
# US fighter squadron to be deployed in South Korea next month (AFP) AFP - A squadron of US Air Force F-15E fighters based in Alaska will fly to South Korea next month for temporary deployment aimed at enhancing US firepower on the Korean peninsula, US authorities said.
#
#
# [Succeeded / Failed / Skipped / Total] 21 / 26 / 4 / 51:  52% 52/100 [42:52<39:34, 49.46s/it]--------------------------------------------- Result 52 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Johnson Back to His Best as D-Backs End Streak  NEW YORK (Reuters) - Randy Johnson struck out 14 batters in  8 1/3 innings to help the Arizona Diamondbacks end a nine-game  losing streak with a 2-0 win over the host New York Mets in the  National League Sunday.
#
#
# [Succeeded / Failed / Skipped / Total] 21 / 27 / 4 / 52:  53% 53/100 [43:47<38:49, 49.57s/it]--------------------------------------------- Result 53 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Restive Maldives eases curfew after rounding up dissidents (AFP) AFP - A curfew in the capital of the Maldives was eased but parliament sessions were put off indefinitely and emergency rule continued following last week's riots, officials and residents said.
#
#
# [Succeeded / Failed / Skipped / Total] 21 / 28 / 4 / 53:  54% 54/100 [44:27<37:52, 49.40s/it]--------------------------------------------- Result 54 ---------------------------------------------
# Sci/tech (100%) --> Business (63%)
#
# Vodafone hires Citi for Cesky bid (TheDeal.com) TheDeal.com - The U.K. mobile giant wants to find a way to disentagle the Czech wireless and fixed-line businesses.
#
# Vodafone hires Citi for Cesky bid (Bloomberg.com) From TheDeal.com - The U.K. mobile giant wants to find a way to disentagle the Czech wireless and fixed-line businesses.
#
#
# [Succeeded / Failed / Skipped / Total] 22 / 28 / 4 / 54:  55% 55/100 [45:27<37:11, 49.60s/it]--------------------------------------------- Result 55 ---------------------------------------------
# Business (100%) --> [FAILED]
#
# Dollar Briefly Hits 4-Wk Low Vs Euro  LONDON (Reuters) - The dollar dipped to a four-week low  against the euro on Monday before rising slightly on  profit-taking, but steep oil prices and weak U.S. data  continued to fan worries about the health of the world's  largest economy.
#
#
# [Succeeded / Failed / Skipped / Total] 22 / 29 / 4 / 55:  56% 56/100 [45:48<35:59, 49.09s/it]--------------------------------------------- Result 56 ---------------------------------------------
# Sci/tech (54%) --> Sports (96%)
#
# Promoting a Shared Vision As Michael Kaleko kept running into people who were getting older and having more vision problems, he realized he could do something about it.
#
# Promoting a Shared Vision As Coach Kaleko kept running into people who were getting older and having more vision problems, he realized he could do something about it.
#
#
# [Succeeded / Failed / Skipped / Total] 23 / 29 / 4 / 56:  57% 57/100 [46:17<34:55, 48.74s/it]--------------------------------------------- Result 57 ---------------------------------------------
# World (95%) --> Business (97%)
#
# India's Tata expands regional footprint via NatSteel buyout (AFP) AFP - India's Tata Iron and Steel Company Ltd. took a strategic step to expand its Asian footprint with the announcement it will buy the Asia-Pacific steel operations of Singapore's NatSteel Ltd.
#
# India's Tata expands regional footprint via NatSteel buyout (AFP) Today - India's Tata Iron and Steel Company Ltd. took a strategic step to expand its Asian footprint with the announcement it will buy the Asia-Pacific steel operations of Singapore's NatSteel Ltd.
#
#
# [Succeeded / Failed / Skipped / Total] 24 / 29 / 4 / 57:  58% 58/100 [47:14<34:12, 48.87s/it]--------------------------------------------- Result 58 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Delegates Urge Cleric to Pull Out of Najaf BAGHDAD, Iraq - Delegates at Iraq's National Conference called on radical Shiite cleric Muqtada al-Sadr to abandon his uprising against U.S. and Iraqi troops and pull his fighters out of a holy shrine in Najaf...
#
#
# [Succeeded / Failed / Skipped / Total] 24 / 30 / 4 / 58:  59% 59/100 [48:08<33:27, 48.96s/it]--------------------------------------------- Result 59 ---------------------------------------------
# Business (100%) --> [FAILED]
#
# Treasuries Slip as Stocks Rally  NEW YORK (Reuters) - U.S. Treasury debt prices slipped on  Monday, though traders characterized the move as profit-taking  rather than any fundamental change in sentiment.
#
#
# [Succeeded / Failed / Skipped / Total] 24 / 31 / 4 / 59:  60% 60/100 [49:06<32:44, 49.11s/it]--------------------------------------------- Result 60 ---------------------------------------------
# Business (100%) --> Sci/tech (71%)
#
# Dollar Rises Vs Euro on Asset Flows Data  NEW YORK (Reuters) - The dollar extended gains against the  euro on Monday after a report on flows into U.S. assets showed  enough of a rise in foreign investments to offset the current  account gap for the month.
#
# Dollar Rises Apple Vs Euro on Ant Flows Data  NEW YORK (Reuters) - The dollar extended gains against the  euro on Monday after a report on flows into U.S. assets showed  enough of a rise in foreign investments to offset the current  account gap for the month.
#
#
# [Succeeded / Failed / Skipped / Total] 25 / 31 / 4 / 60:  61% 61/100 [50:08<32:03, 49.33s/it]--------------------------------------------- Result 61 ---------------------------------------------
# Sports (100%) --> Sci/tech (75%)
#
# Sutton Adds Haas, Cink to Ryder Cup Team  MILWAUKEE (Sports Network) - U.S. Ryder Cup captain Hal  Sutton finalized his team on Monday when he announced the  selections of Jay Haas and Stewart Cink as his captain's picks.
#
# App Adds Haas, Cink to Ryder Cup Team  Blog (Apple Network) - U.S. Ryder Cup captain Hal  Sutton finalized his team on Monday when he announced the  selections of Jay Haas and Stewart Cink as his captain's picks.
#
#
# [Succeeded / Failed / Skipped / Total] 26 / 31 / 4 / 61:  62% 62/100 [51:09<31:21, 49.50s/it]--------------------------------------------- Result 62 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Haas and Cink Selected for Ryder Cup Team Jay Haas joined Stewart Cink as the two captain's picks for a U.S. team that will try to regain the cup from Europe next month.
#
#
# [Succeeded / Failed / Skipped / Total] 26 / 32 / 4 / 62:  63% 63/100 [51:58<30:31, 49.51s/it]--------------------------------------------- Result 63 ---------------------------------------------
# Sports (100%) --> Sci/tech (84%)
#
# Natalie Coughlin Wins 100M Backstroke (AP) AP - American Natalie Coughlin won Olympic gold in the 100-meter backstroke Monday night. Coughlin, the only woman ever to swim under 1 minute in the event, finished first in 1 minute, 0.37 seconds. Kirsty Coventry of Zimbabwe, who swims at Auburn University in Alabama, earned the silver in 1:00.50. Laure Manaudou of France took bronze in 1:00.88.
#
# Natalie Coughlin Wins 100M Backstroke (AP) AP - American astronaut Natalie Coughlin won Olympic gold in the 100-meter backstroke Monday night. Coughlin, the only woman ever to swim under 1 minute in the event, finished first in 1 minute, 0.37 seconds. Kirsty Coventry of Zimbabwe, who swims at Auburn University in Alabama, earned the silver in 1:00.50. Laure Manaudou of France took bronze in 1:00.88.
#
#
# [Succeeded / Failed / Skipped / Total] 27 / 32 / 4 / 63:  64% 64/100 [52:57<29:47, 49.65s/it]--------------------------------------------- Result 64 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# Oracle Overhauls Sales-Side Apps for CRM Suite (NewsFactor) NewsFactor - Oracle (Nasdaq: ORCL) has revamped its sales-side CRM applications in version 11i.10 of its sales, marketing, partner relationship management and e-commerce application.
#
#
# [Succeeded / Failed / Skipped / Total] 27 / 33 / 4 / 64:  65% 65/100 [54:12<29:11, 50.04s/it]--------------------------------------------- Result 65 ---------------------------------------------
# World (100%) --> [FAILED]
#
# UN launches 210-million-dollar appeal for flood-hit Bangladesh (AFP) AFP - The United Nations launched an appeal here for 210 million dollars to help flood victims facing "grave" food shortages after two-thirds of Bangladesh was submerged, destroying crops and killing more than 700 people.
#
#
# [Succeeded / Failed / Skipped / Total] 27 / 34 / 4 / 65:  66% 66/100 [55:03<28:21, 50.05s/it]--------------------------------------------- Result 66 ---------------------------------------------
# Sci/tech (93%) --> Business (73%)
#
# Indian state rolls out wireless broadband Government in South Indian state of Kerala sets up wireless kiosks as part of initiative to bridge digital divide.
#
# Indian state rolls out Aadhaar wireless tender The Government in South Indian state of Kerala sets up wireless kiosks as part of initiative to bridge digital divide.
#
#
# [Succeeded / Failed / Skipped / Total] 28 / 34 / 4 / 66:  67% 67/100 [55:59<27:34, 50.14s/it]--------------------------------------------- Result 67 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Hurricane Survivors Wait for Water, Gas PUNTA GORDA, Fla. - Urban rescue teams, insurance adjusters and National Guard troops scattered across Florida Monday to help victims of Hurricane Charley and deliver water and other supplies to thousands of people left homeless...
#
#
# [Succeeded / Failed / Skipped / Total] 28 / 35 / 4 / 67:  68% 68/100 [56:56<26:47, 50.24s/it]--------------------------------------------- Result 68 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Jackson Squares Off With Prosecutor SANTA MARIA, Calif. - Fans of Michael Jackson erupted in cheers Monday as the pop star emerged from a double-decker tour bus and went into court for a showdown with the prosecutor who has pursued him for years on child molestation charges...
#
#
# [Succeeded / Failed / Skipped / Total] 28 / 36 / 4 / 68:  69% 69/100 [58:03<26:05, 50.49s/it]--------------------------------------------- Result 69 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Bobcats Trade Drobnjak to Hawks for Pick (AP) AP - The Charlotte Bobcats traded center Predrag Drobnjak to the Atlanta Hawks on Monday for a second round pick in the 2005 NBA draft.
#
#
# [Succeeded / Failed / Skipped / Total] 28 / 37 / 4 / 69:  70% 70/100 [59:10<25:21, 50.71s/it]--------------------------------------------- Result 70 ---------------------------------------------
# World (100%) --> Sci/tech (67%)
#
# Suspect charged in abduction, sexual assault of 11-year-old girl (Canadian Press) Canadian Press - LANGLEY, B.C. (CP) - Police have arrested a man in the kidnapping and sexual assault of an 11-year-old girl that frightened this suburban Vancouver community last week.
#
# Suspect charged in abduction, sexual cyber assault of 11-year-old girl (Canadian Press) and Canadian Mail - LANGLEY, B.C. (CP) - Police have arrested a man in the kidnapping and sexual assault of an 11-year-old girl that frightened this suburban Vancouver community last week.
#
#
# [Succeeded / Failed / Skipped / Total] 29 / 37 / 4 / 70:  71% 71/100 [1:00:03<24:31, 50.75s/it]--------------------------------------------- Result 71 ---------------------------------------------
# Sci/tech (99%) --> [FAILED]
#
# China's Red Flag Linux to focus on enterprise Red Flag Software Co., the company behind China's leading Linux client distribution, plans to focus more on its server operating system and enterprise customers, the company's acting president said.
#
#
# [Succeeded / Failed / Skipped / Total] 29 / 38 / 4 / 71:  72% 72/100 [1:01:14<23:48, 51.03s/it]--------------------------------------------- Result 72 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# AOL Properties Sign Girafa For Thumbnail Search Images AOL Properties Sign Girafa For Thumbnail Search Images\\Girafa.com Inc. announced today that the CompuServe, Netscape, AIM and ICQ properties of America Online, Inc., have signed an agreement with Girafa to use Girafa's thumbnail search images as an integrated part of their search results.\\Using Girafa's thumbnail search service, search users can ...
#
#
# [Succeeded / Failed / Skipped / Total] 29 / 39 / 4 / 72:  73% 73/100 [1:02:16<23:02, 51.19s/it]--------------------------------------------- Result 73 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# Cassini Spies Two Little Saturn Moons (AP) AP - NASA's Cassini spacecraft has spied two new little moons around satellite-rich Saturn, the space agency said Monday.
#
#
# [Succeeded / Failed / Skipped / Total] 29 / 40 / 4 / 73:  74% 74/100 [1:02:45<22:02, 50.88s/it]--------------------------------------------- Result 74 ---------------------------------------------
# World (99%) --> Sci/tech (87%)
#
# On front line of AIDS in Russia An industrial city northwest of Moscow struggles as AIDS hits a broader population.
#
# On front line of construction in Russia An industrial city northwest of Moscow struggles as automation hits a broader population.
#
#
# [Succeeded / Failed / Skipped / Total] 30 / 40 / 4 / 74:  75% 75/100 [1:03:44<21:14, 51.00s/it]--------------------------------------------- Result 75 ---------------------------------------------
# Sci/tech (97%) --> [FAILED]
#
# Nobel Laureate Decries Stem Cell Limits (AP) AP - A Nobel laureate in medicine said Monday the Bush administration's limits on funding for embryonic stem cell research effectively have stopped the clock on American scientists' efforts to develop treatments for a host of chronic, debilitating diseases.
#
#
# [Succeeded / Failed / Skipped / Total] 30 / 41 / 4 / 75:  76% 76/100 [1:04:42<20:25, 51.08s/it]--------------------------------------------- Result 76 ---------------------------------------------
# Sports (100%) --> Sci/tech (78%)
#
# Jury Can Hear of Kobe Accuser's Sex Life (AP) AP - Prosecutors suffered another setback Monday in the Kobe Bryant sexual assault case, losing a last-ditch attempt to keep the NBA star's lawyers from telling jurors about the alleged victim's sex life.
#
# Jury Can Hear of Internet Accuser's Sex Life (AP) AP - Prosecutors suffered another setback Monday in the Kobe Bryant sexual assault case, losing a last-ditch attempt to keep the NBA star's lawyers from telling jurors about the alleged online sex life.
#
#
# [Succeeded / Failed / Skipped / Total] 31 / 41 / 4 / 76:  77% 77/100 [1:05:40<19:37, 51.18s/it]--------------------------------------------- Result 77 ---------------------------------------------
# World (100%) --> Sci/tech (98%)
#
# North Korea Talks Still On, China Tells Downer (Reuters) Reuters - China has said no date has been set for\working-level talks on the North Korean nuclear crisis and gave\no indication that the meeting has been canceled, Australian\Foreign Minister Alexander Downer said on Tuesday.
#
# North Korea Talks Still On, China Tells Downer (Reuters) Reuters - China has said no date has been set for\climate talks on the North Korean nuclear crisis and gave\no indication that the meeting has been canceled, NASA\Foreign Minister Alexander Downer said on Tuesday.
#
#
# [Succeeded / Failed / Skipped / Total] 32 / 41 / 4 / 77:  78% 78/100 [1:06:33<18:46, 51.19s/it]--------------------------------------------- Result 78 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Griffin to Anchor D-Line The Redskins expect huge things from 300-pound Cornelius Griffin, who was signed to aid the team's weakest unit - the defensive line.
#
#
# [Succeeded / Failed / Skipped / Total] 32 / 42 / 4 / 78:  79% 79/100 [1:07:31<17:56, 51.28s/it]--------------------------------------------- Result 79 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Last American defector in North Korea agrees to tell story (AFP) AFP - The last surviving American defector to communist North Korea wants to tell his story to put a human face on the Stalinist state which he believes is unfairly vilified abroad, British film-makers said.
#
#
# [Succeeded / Failed / Skipped / Total] 32 / 43 / 4 / 79:  80% 80/100 [1:07:45<16:56, 50.82s/it]--------------------------------------------- Result 80 ---------------------------------------------
# World (61%) --> Sports (96%)
#
# Live: Olympics day four Richard Faulds and Stephen Parry are going for gold for Great Britain on day four in Athens.
#
# Tomorrow: Olympics day four Richard Faulds and Stephen Parry are going for gold for Great Britain on day four in Athens.
#
#
# [Succeeded / Failed / Skipped / Total] 33 / 43 / 4 / 80:  81% 81/100 [1:08:31<16:04, 50.76s/it]--------------------------------------------- Result 81 ---------------------------------------------
# World (100%) --> Sci/tech (94%)
#
# Kerry Widens Lead in California, Poll Finds (Reuters) Reuters - Democratic challenger John Kerry\has a commanding lead over President Bush in California of 54\percent to 38 percent among likely voters, a poll released on\Tuesday found.
#
# Kerry Widens Lead in California, Poll Finds (Reuters) Copyright Reuters - Democratic challenger John Kerry\has a commanding lead online over President Bush in California of 54\percent to 38 percent among likely voters, a poll released on\Tuesday found.
#
#
# [Succeeded / Failed / Skipped / Total] 34 / 43 / 4 / 81:  82% 82/100 [1:09:02<15:09, 50.52s/it]--------------------------------------------- Result 82 ---------------------------------------------
# Sports (100%) --> Business (64%)
#
# Capacity Crowds at Beach Volleyball Rock the Joint  ATHENS (Reuters) - At the beach volleyball, the 2004  Olympics is a sell-out, foot-stomping success.
#
# Capacity Crowds at Beach Volleyball Rock the Joint  Stock (Reuters) - At the beach volleyball, the 2004  Olympics is a sell-out, foot-stomping technological success.
#
#
# [Succeeded / Failed / Skipped / Total] 35 / 43 / 4 / 82:  83% 83/100 [1:10:00<14:20, 50.61s/it]--------------------------------------------- Result 83 ---------------------------------------------
# Business (100%) --> [FAILED]
#
# Dollar Near Recent Lows, Awaits ZEW/CPI  LONDON (Reuters) - The dollar held steady near this week's  four-week low against the euro on Tuesday with investors  awaiting a German investor confidence survey and U.S. consumer  inflation numbers to shed light on the direction.
#
#
# [Succeeded / Failed / Skipped / Total] 35 / 44 / 4 / 83:  83% 83/100 [1:10:00<14:20, 50.61s/it]--------------------------------------------- Result 84 ---------------------------------------------
# Sci/tech (97%) --> [38:5:240m[SKIPPED]
#
# Intel to delay product aimed for high-definition TVs SAN FRANCISCO -- In the latest of a series of product delays, Intel Corp. has postponed the launch of a video display chip it had previously planned to introduce by year end, putting off a showdown with Texas Instruments Inc. in the fast-growing market for high-definition television displays.
#
#
# [Succeeded / Failed / Skipped / Total] 35 / 44 / 5 / 84:  85% 85/100 [1:10:31<12:26, 49.78s/it]--------------------------------------------- Result 85 ---------------------------------------------
# World (97%) --> Sports (88%)
#
# Venezuela vote keeps Chavez as president CARACAS -- Venezuelans voted resoundingly to keep firebrand populist Hugo Chavez as their president in a victory that drew noisy reactions yesterday from both sides in the streets. International observers certified the results as clean and accurate.
#
# Venezuela vote keeps Chavez as president CARACAS -- Venezuelans voted resoundingly to keep firebrand populist Hugo Chavez as their president in a victory that drew noisy reactions yesterday from both sides in the streets. FIFA International observers certified the results as clean and accurate.
#
#
# [Succeeded / Failed / Skipped / Total] 36 / 44 / 5 / 85:  86% 86/100 [1:11:25<11:37, 49.83s/it]--------------------------------------------- Result 86 ---------------------------------------------
# World (100%) --> Sci/tech (69%)
#
# Jailing of HK democrat in China 'politically motivated' (AFP) AFP - Hong Kong democrats accused China of jailing one of their members on trumped-up prostitution charges in a bid to disgrace a political movement Beijing has been feuding with for seven years.
#
# Jailing of HK democrat in China 'politically motivated' (AFP) AFP - Hong Kong internet democrats accused China of jailing one of their members online on trumped-up prostitution charges in a bid to disgrace a political movement Beijing has been feuding with for seven years.
#
#
# [Succeeded / Failed / Skipped / Total] 37 / 44 / 5 / 86:  87% 87/100 [1:12:02<10:45, 49.69s/it]--------------------------------------------- Result 87 ---------------------------------------------
# Business (100%) --> World (52%)
#
# Kmart Swings to Profit in 2Q; Stock Surges (AP) AP - Shares of Kmart Holding Corp. surged 17 percent Monday after the discount retailer reported a profit for the second quarter and said chairman and majority owner Edward Lampert is now free to invest the company's  #36;2.6 billion in surplus cash.
#
# Kmart Swings to Profit in 2Q; Stock Surges (AP) AP - Shares of Kmart Holding Corp. surged 17 percent Monday after the discount company reported a profit for the second quarter and said chairman and majority owner Edward Lampert is now free to invest the company's  #36;2.6 billion in surplus cash.
#
#
# [Succeeded / Failed / Skipped / Total] 38 / 44 / 5 / 87:  88% 88/100 [1:12:34<09:53, 49.48s/it]--------------------------------------------- Result 88 ---------------------------------------------
# World (100%) --> Sports (97%)
#
# Fischer's Fiancee: Marriage Plans Genuine (AP) AP - Former chess champion Bobby Fischer's announcement thathe is engaged to a Japanese woman could win him sympathy among Japanese officials and help him avoid deportation to the United States, his fiancee and one of his supporters said Tuesday.
#
# Fischer's Fiancee: Marriage Plans Genuine (AP) AP - Former NBA champion Bobby Fischer's announcement thathe is engaged to a Japanese woman could win him sympathy among Japanese officials and help him avoid deportation to the United States, his fiancee and one of his supporters said Tuesday.
#
#
# [Succeeded / Failed / Skipped / Total] 39 / 44 / 5 / 88:  89% 89/100 [1:13:29<09:05, 49.55s/it]--------------------------------------------- Result 89 ---------------------------------------------
# World (100%) --> [FAILED]
#
# U.S. Misses Cut in Olympic 100 Free ATHENS, Greece - Top American sprinters Jason Lezak and Ian Crocker missed the cut in the Olympic 100-meter freestyle preliminaries Tuesday, a stunning blow for a country that had always done well in the event.    Pieter van den Hoogenband of the Netherlands and Australian Ian Thorpe advanced to the evening semifinal a day after dueling teenager Michael Phelps in the 200 freestyle, won by Thorpe...
#
#
# [Succeeded / Failed / Skipped / Total] 39 / 45 / 5 / 89:  90% 90/100 [1:14:30<08:16, 49.67s/it]--------------------------------------------- Result 90 ---------------------------------------------
# Sci/tech (99%) --> [FAILED]
#
# Consumers Would Pay In Phone Proposal A proposal backed by a coalition of telephone carriers would cut billions of dollars in fees owed by long-distance companies to regional phone giants but would allow the regional companies to make up some of the difference by raising monthly phone bills for millions of consumers. &lt;FONT face="verdana,MS Sans Serif,arial,helvetica" size="-2"\ color="#666666"&gt;&lt;B&gt;-The Washington Post&lt;/B&gt;&lt;/FONT&gt;
#
#
# [Succeeded / Failed / Skipped / Total] 39 / 46 / 5 / 90:  91% 91/100 [1:15:32<07:28, 49.81s/it]--------------------------------------------- Result 91 ---------------------------------------------
# World (100%) --> [FAILED]
#
# U.S. Brokers Cease-fire in Western Afghanistan  KABUL (Reuters) - The United States has brokered a  cease-fire between a renegade Afghan militia leader and the  embattled governor of the western province of Herat,  Washington's envoy to Kabul said Tuesday.
#
#
# [Succeeded / Failed / Skipped / Total] 39 / 47 / 5 / 91:  92% 92/100 [1:15:46<06:35, 49.42s/it]--------------------------------------------- Result 92 ---------------------------------------------
# Business (76%) --> Sci/tech (99%)
#
# Sneaky Credit Card Tactics Keep an eye on your credit card issuers -- they may be about to raise your rates.
#
# Sneaky Credit Card Tactics Video Keep an eye on your credit card issuers -- they may be about to raise your rates.
#
#
# [Succeeded / Failed / Skipped / Total] 40 / 47 / 5 / 92:  93% 93/100 [1:16:50<05:47, 49.57s/it]--------------------------------------------- Result 93 ---------------------------------------------
# Sci/tech (98%) --> [FAILED]
#
# Intel Delays Launch of Projection TV Chip In another product postponement, semiconductor giant Intel Corp. said it won't be offering a chip for projection TVs by the end of 2004 as it had announced earlier this year.
#
#
# [Succeeded / Failed / Skipped / Total] 40 / 48 / 5 / 93:  94% 94/100 [1:17:36<04:57, 49.54s/it]--------------------------------------------- Result 94 ---------------------------------------------
# Business (100%) --> Sci/tech (80%)
#
# Fund pessimism grows NEW YORK (CNN/Money) - Money managers are growing more pessimistic about the economy, corporate profits and US stock market returns, according to a monthly survey by Merrill Lynch released Tuesday.
#
# Tech pessimism grows online NEW YORK (CNN/Money) - Money managers are growing more pessimistic about the economy, corporate profits and US stock market returns, according to a monthly survey by Merrill Lynch released Tuesday.
#
#
# [Succeeded / Failed / Skipped / Total] 41 / 48 / 5 / 94:  95% 95/100 [1:17:59<04:06, 49.26s/it]--------------------------------------------- Result 95 ---------------------------------------------
# Sports (91%) --> World (73%)
#
# Kederis proclaims innocence Olympic champion Kostas Kederis today left hospital ahead of his date with IOC inquisitors claiming his innocence and vowing:  quot;After the crucifixion comes the resurrection. quot; ...
#
# Kederis proclaims innocence Olympic champion Kostas Kederis today left hospital ahead of his date with Zionist inquisitors claiming his innocence and vowing:  quot;After the crucifixion comes the resurrection. quot; ...
#
#
# [Succeeded / Failed / Skipped / Total] 42 / 48 / 5 / 95:  96% 96/100 [1:19:06<03:17, 49.44s/it]--------------------------------------------- Result 96 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Eriksson doesn #39;t feel any extra pressure following scandal NEWCASTLE, England (AP) - England coach Sven-Goran Eriksson said Tuesday he isn #39;t under any extra pressure in the aftermath of a scandal that damaged the Football Association #39;s reputation.
#
#
# [Succeeded / Failed / Skipped / Total] 42 / 49 / 5 / 96:  97% 97/100 [1:20:06<02:28, 49.55s/it]--------------------------------------------- Result 97 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Injured Heskey to miss England friendly NEWCASTLE, England (AP) - Striker Emile Heskey has pulled out of the England squad ahead of Wednesday #39;s friendly against Ukraine because of a tight hamstring, the Football Association said Tuesday.
#
#
# [Succeeded / Failed / Skipped / Total] 42 / 50 / 5 / 97:  98% 98/100 [1:21:24<01:39, 49.85s/it]--------------------------------------------- Result 98 ---------------------------------------------
# Business (100%) --> [FAILED]
#
# Staples Profit Up, to Enter China Market  NEW YORK (Reuters) - Staples Inc. &lt;A HREF="http://www.investor.reuters.com/FullQuote.aspx?ticker=SPLS.O target=/stocks/quickinfo/fullquote"&gt;SPLS.O&lt;/A&gt;, the top U.S.  office products retailer, on Tuesday reported a 39 percent jump  in quarterly profit, raised its full-year forecast and said it  plans to enter the fast-growing Chinese market, sending its  shares higher.
#
#
# [Succeeded / Failed / Skipped / Total] 42 / 51 / 5 / 98:  99% 99/100 [1:22:24<00:49, 49.94s/it]--------------------------------------------- Result 99 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Delegation Is Delayed Before Reaching Najaf AGHDAD, Iraq, Aug. 17  A delegation of Iraqis was delayed for security reasons today but still intended to visit Najaf to try to convince a rebellious Shiite cleric and his militia to evacuate a shrine in the holy city and end ...
#
#
# [Succeeded / Failed / Skipped / Total] 42 / 52 / 5 / 99: 100% 100/100 [1:22:58<00:00, 49.78s/it]--------------------------------------------- Result 100 ---------------------------------------------
# Business (100%) --> Sci/tech (51%)
#
# Consumer Prices Down, Industry Output Up  WASHINGTON (Reuters) - U.S. consumer prices dropped in July  for the first time in eight months as a sharp run up in energy  costs reversed, the government said in a report that suggested  a slow rate of interest rate hikes is likely.
#
# Consumer Prices Down, Tech Industry Output Up  WASHINGTON (Reuters) - U.S. consumer prices dropped in July  for the first time in eight months as a sharp run up in energy  costs reversed, the government said in a report that suggested  a slow rate of interest rate hikes is likely.
#
#
# [Succeeded / Failed / Skipped / Total] 43 / 52 / 5 / 100: 100% 100/100 [1:22:58<00:00, 49.78s/it]
#
# Token indices sequence length is longer than the specified maximum sequence length for this model (2217 > 1024). Running this sequence through the model will result in indexing errors
# +-------------------------------+---------+
# | Attack Results                |         |
# +-------------------------------+---------+
# | Number of successful attacks: | 43      |
# | Number of failed attacks:     | 52      |
# | Number of skipped attacks:    | 5       |
# | Original accuracy:            | 95.0%   |
# | Accuracy under attack:        | 52.0%   |
# | Attack success rate:          | 45.26%  |
# | Average perturbed word %:     | 40.86%  |
# | Average num. words per input: | 43.16   |
# | Avg num queries:              | 4359.93 |
# | Average Original Perplexity:  | 76.36   |
# | Average Attack Perplexity:    | 87.46   |
# | Average Attack USE Score:     | 0.9     |
# +-------------------------------+---------+

# %% [markdown]
# Text attack did not complete due to lack of resources

# %% [markdown]
# Looks like our model was 94% successful (makes sense - same evaluation set as `textattack eval`!), meaning that TextAttack attacked the model with 94% examples (since the attack won't run if an example is originally mispredicted). The attack success rate was %, meaning that Clare failed to find an adversarial example only % (1 out of ) of the time.

# %%
# !textattack attack --recipe textfooler --num-examples 100 --model ./outputs/2023-12-17-15-56-36-938484/best_model/ --dataset-from-huggingface ag_news --dataset-split test --query-budget 5000   --enable-advance-metrics
# Out:
# 2023-12-17 19:49:07.790520: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 19:49:07.790569: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 19:49:07.790616: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 19:49:08.892406: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-17 19:49:11.644213: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# textattack: Loading datasets dataset ag_news, split test.
# textattack: Downloading https://textattack.s3.amazonaws.com/word_embeddings/paragramcf.
# 100% 481M/481M [00:17<00:00, 27.3MB/s]
# textattack: Unzipping file /root/.cache/textattack/tmp9vepsfty.zip to /root/.cache/textattack/word_embeddings/paragramcf.
# textattack: Successfully saved word_embeddings/paragramcf to cache.
# textattack: Unknown if model of class <class 'transformers.models.distilbert.modeling_distilbert.DistilBertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  delete
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  WordSwapEmbedding(
#     (max_candidates):  50
#     (embedding):  WordEmbedding
#   )
#   (constraints):
#     (0): WordEmbeddingDistance(
#         (embedding):  WordEmbedding
#         (min_cos_sim):  0.5
#         (cased):  False
#         (include_unknown_words):  True
#         (compare_against_original):  True
#       )
#     (1): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#     (2): UniversalSentenceEncoder(
#         (metric):  angular
#         (threshold):  0.840845057
#         (window_size):  15
#         (skip_text_shorter_than_window):  True
#         (compare_against_original):  False
#       )
#     (3): RepeatModification
#     (4): StopwordModification
#     (5): InputColumnModification(
#         (matching_column_labels):  ['premise', 'hypothesis']
#         (columns_to_ignore):  {'premise'}
#       )
#   (is_black_box):  True
# )
#
#   1% 1/100 [00:07<12:27,  7.55s/it]--------------------------------------------- Result 1 ---------------------------------------------
# Business (100%) --> World (61%)
#
# Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
#
# Fears for T N pension after debating Unionists representing workers at Turner   Newall say they are 'disappointed' after talks with stricken mamma stabilised Govt Mogul.
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 0 / 0 / 1:   2% 2/100 [00:12<10:13,  6.26s/it]--------------------------------------------- Result 2 ---------------------------------------------
# Sci/tech (100%) --> World (54%)
#
# The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
#
# The Raza is On: Second Private Grupo Sets Embarked Dated for Humanitarian Spaceflight (SPATIAL.kom) DISTANCE.com - CANADIENS, Canadian -- A second\chore of rocketeers contested for the  #36;10 million Ansari X Bonus, a contenders for\covertly financiers suborbital separator aircraft, is solemnly decreed the first\lancer day for its desolate blast.
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 0 / 0 / 2:   3% 3/100 [00:16<09:08,  5.66s/it]--------------------------------------------- Result 3 ---------------------------------------------
# Sci/tech (100%) --> World (53%)
#
# Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
#
# Ky. Enterprising Yuan Premiums to Scrutinize Peptides (AP) APS - para company established by a chemical coroner at the Campuses of Paducah won a dons to enacted a method of manufacture tougher peptides, which are terse twine of neurotransmitters vinegar, the enhancing streets of neurotransmitters.
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 0 / 0 / 3:   4% 4/100 [00:18<07:17,  4.55s/it]--------------------------------------------- Result 4 ---------------------------------------------
# Sci/tech (100%) --> Sports (78%)
#
# Prediction Unit Helps Forecast Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
#
# Prospect Unit Helps Forecast Wildfires (AP) PA - It's barely blew when Micky Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Windy will pick up, moist places will dry and flames will roar.
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 0 / 0 / 4:   5% 5/100 [00:19<06:04,  3.84s/it]--------------------------------------------- Result 5 ---------------------------------------------
# Sci/tech (99%) --> World (52%)
#
# Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
#
# Calif. Aims to Limiting Farm-Related Cigarette (AP) AP - Sud California's smog-fighting agency went after emissions of the bovine crowd Friday, adopting the nation's first rules to reduce air grime from dairy cow manure.
#
#
# [Succeeded / Failed / Skipped / Total] 5 / 0 / 0 / 5:   6% 6/100 [00:25<06:34,  4.20s/it]--------------------------------------------- Result 6 ---------------------------------------------
# Sci/tech (99%) --> Business (54%)
#
# Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
#
# Open Letter Against Ingles Pirating Indoctrination in Schools The British Department for Learn and Skilful (DfES) lately launched a "Music Statement" campaign, with the ostensible geared of educating the next generation of British musicians. Woefully, they also teamed up with the music industry (IME, and various artists) to make this popular. EMI has soberly haggling their fin well, where that children in our schools will now be fooled about the illegality of offload music.The indifference and audacity of this ha to me a petite, so I wrote an commencement letter to the DfES about it. Unfortunately, it's pedantic, as me dunno you have to be when writer to administration representatives. But I looks you find it useful, and maybe feel inspired to do something similar, if or when the same thing has happened in your area.
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 0 / 0 / 6:   7% 7/100 [00:35<07:52,  5.08s/it]--------------------------------------------- Result 7 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 1 / 0 / 7:   8% 8/100 [00:48<09:13,  6.01s/it]--------------------------------------------- Result 8 ---------------------------------------------
# Sci/tech (100%) --> Business (53%)
#
# FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
#
# FOAFKey: FOAF, PGP, Paramount Distribution, and Bloom Strainer \\FOAF/ONION  and clover strainer receives a parcel of thrilling commodities for sociable\lattice and whitelist circulation.\\I insights we can vaya one grade superior unless and therein GPG/OpenPGP principal\fingerpring distribution in the FOAF filing for simple web-of-trust footing indispensable\distribution.\\What if we used FOAF and include the PGP momentous fingerprint(s) for identities?\That could involving a shipment.  You insert the PGP elementary prints within the FOAF\deposits of your straight buddy and then insert a bloom screening of the PGP elementary\characterization of your unmitigated whitelist (the originate FOAF depot would of trajectory must\to viens encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
#
#
# [Succeeded / Failed / Skipped / Total] 7 / 1 / 0 / 8:   9% 9/100 [00:48<08:15,  5.44s/it]--------------------------------------------- Result 9 ---------------------------------------------
# Sci/tech (99%) --> World (51%)
#
# E-mail scam targets police chief Wiltshire Police warns about "phishing" after its fraud squad chief was targeted.
#
# E-mail scam targets police chief Chelmsford Gardai warns about "phishing" after its defrauding battalion chief was targeted.
#
#
# [Succeeded / Failed / Skipped / Total] 8 / 1 / 0 / 9:  10% 10/100 [00:49<07:25,  4.95s/it]--------------------------------------------- Result 10 ---------------------------------------------
# Sci/tech (87%) --> Business (68%)
#
# Card fraud unit nets 36,000 cards In its first two years, the UK's dedicated card fraud unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
#
# Card defrauding unit tenderloin 36,000 cards In its first two years, the UK's dedicated card fraud unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
#
#
# [Succeeded / Failed / Skipped / Total] 9 / 1 / 0 / 10:  11% 11/100 [00:50<06:50,  4.61s/it]--------------------------------------------- Result 11 ---------------------------------------------
# Sci/tech (98%) --> Business (58%)
#
# Group to Propose New High-Speed Wireless Format  LOS ANGELES (Reuters) - A group of technology companies  including Texas Instruments Inc. &lt;TXN.N&gt;, STMicroelectronics  &lt;STM.PA&gt; and Broadcom Corp. &lt;BRCM.O&gt;, on Thursday said they  will propose a new wireless networking standard up to 10 times  the speed of the current generation.
#
# Grupo to Proposed New High-Speed Wireless Forma  LOS ANGELES (Reuters) - A group of technology companies  including Oklahoma Apparatus Inc. &lt;TXN.N&gt;, STMicroelectronics  &lt;STM.PA&gt; and Broadcom Corp. &lt;BRCM.O&gt;, on Thursday said they  will propose a new wireless grates standard up to 10 times  the speed of the current generation.
#
#
# [Succeeded / Failed / Skipped / Total] 10 / 1 / 0 / 11:  12% 12/100 [00:52<06:24,  4.37s/it]--------------------------------------------- Result 12 ---------------------------------------------
# Sci/tech (98%) --> Business (50%)
#
# Apple Launches Graphics Software, Video Bundle  LOS ANGELES (Reuters) - Apple Computer Inc.&lt;AAPL.O&gt; on  Tuesday began shipping a new program designed to let users  create real-time motion graphics and unveiled a discount  video-editing software bundle featuring its flagship Final Cut  Pro software.
#
# Shoemaker Spear Images Software, Films Pooling  LOS ANGELES (Reuters) - Apple Computer Inc.&ensign;AAPL.O&gt; on  Tuesday began shipping a new program designed to let users  create real-time motion graphics and unmask a discount  video-editing software bundle championship its flagship Final Cut  Pro software.
#
#
# [Succeeded / Failed / Skipped / Total] 11 / 1 / 0 / 12:  13% 13/100 [00:53<05:59,  4.13s/it]--------------------------------------------- Result 13 ---------------------------------------------
# Sci/tech (99%) --> Business (52%)
#
# Dutch Retailer Beats Apple to Local Download Market  AMSTERDAM (Reuters) - Free Record Shop, a Dutch music  retail chain, beat Apple Computer Inc. to market on Tuesday  with the launch of a new download service in Europe's latest  battleground for digital song services.
#
# Dutch Retailer Sweeps Pizza to Local Dumping Market  AMSTERDAM (Reuters) - Free Record Shop, a Dutch music  sellers chain, dominating Apple Computer Inc. to sold on Tuesday  with the launch of a new download service in Europe's latest  battleground for digital song services.
#
#
# [Succeeded / Failed / Skipped / Total] 12 / 1 / 0 / 13:  14% 14/100 [00:54<05:37,  3.93s/it]--------------------------------------------- Result 14 ---------------------------------------------
# Sci/tech (95%) --> World (51%)
#
# Super ant colony hits Australia A giant 100km colony of ants  which has been discovered in Melbourne, Australia, could threaten local insect species.
#
# Super ant colonised hits Australia A giant 100km colony of gorillas  which has been hollowed in Homestead, Australians, could threaten local bug species.
#
#
# [Succeeded / Failed / Skipped / Total] 13 / 1 / 0 / 14:  15% 15/100 [00:56<05:20,  3.77s/it]--------------------------------------------- Result 15 ---------------------------------------------
# Sci/tech (86%) --> World (51%)
#
# Socialites unite dolphin groups Dolphin groups, or "pods", rely on socialites to keep them from collapsing, scientists claim.
#
# Socialites unity dolphin organisations Dolphin syndicates, or "pods", tally on millionaires to kept them from crumbled, scientists claim.
#
#
# [Succeeded / Failed / Skipped / Total] 14 / 1 / 0 / 15:  16% 16/100 [00:57<04:59,  3.56s/it]--------------------------------------------- Result 16 ---------------------------------------------
# Sci/tech (78%) --> World (55%)
#
# Teenage T. rex's monster growth Tyrannosaurus rex achieved its massive size due to an enormous growth spurt during its adolescent years.
#
# Teenage T. rex's monster grow Carnivores rex achieved its massive size due to an enormous growth spurt during its adolescent years.
#
#
# [Succeeded / Failed / Skipped / Total] 15 / 1 / 0 / 16:  17% 17/100 [00:59<04:49,  3.48s/it]--------------------------------------------- Result 17 ---------------------------------------------
# Sci/tech (100%) --> Business (61%)
#
# Scientists Discover Ganymede has a Lumpy Interior Jet Propulsion Lab -- Scientists have discovered irregular lumps beneath the icy surface of Jupiter's largest moon, Ganymede. These irregular masses may be rock formations, supported by Ganymede's icy shell for billions of years...
#
# Scientists Discovery Ganymede has a Rubbery Nationale Airbus Propulsion Laboratories -- Investigators have discovered irregular lumps beneath the icy surface of Jupiter's largest moon, Ganymede. These unforeseeable masses may be roque formations, helping by Ganymede's icy shell for billions of years...
#
#
# [Succeeded / Failed / Skipped / Total] 16 / 1 / 0 / 17:  18% 18/100 [01:02<04:46,  3.50s/it]--------------------------------------------- Result 18 ---------------------------------------------
# Sci/tech (100%) --> World (51%)
#
# Mars Rovers Relay Images Through Mars Express European Space Agency -- ESAs Mars Express has relayed pictures from one of NASA's Mars rovers for the first time, as part of a set of interplanetary networking demonstrations.     The demonstrations pave the way for future Mars missions to draw on joint interplanetary networking capabilities...
#
# March Orbiter Relay Films For March Express European Space Organisation -- ESAs Marr Openly is conveys pictures from one of NASA's Marse orbiter for the first term, as pieces of a configure of interplanetary networks protesters.     Both demonstrations pave the way for subsequent March mandates to draw on bilateral interplanetary networks jurisdiction...
#
#
# [Succeeded / Failed / Skipped / Total] 17 / 1 / 0 / 18:  19% 19/100 [01:04<04:35,  3.40s/it]--------------------------------------------- Result 19 ---------------------------------------------
# Sci/tech (100%) --> Business (62%)
#
# Rocking the Cradle of Life When did life begin? One evidential clue stems from the fossil records in Western Australia, although whether these layered sediments are biological or chemical has spawned a spirited debate. Oxford researcher, Nicola McLoughlin, describes some of the issues in contention.
#
# Rocking the Bed of Livelihood When did life begin? One evidential clue derives from the hominid records in Western Aussie, although whether these layered sedimentary are biological or chemical has spawned a spirited debating. Bloomsbury fellows, Nicola McLoughlin, portraying some of the issues in contention.
#
#
# [Succeeded / Failed / Skipped / Total] 18 / 1 / 0 / 19:  20% 20/100 [01:05<04:23,  3.30s/it]--------------------------------------------- Result 20 ---------------------------------------------
# Sci/tech (99%) --> Business (56%)
#
# Storage, servers bruise HP earnings update Earnings per share rise compared with a year ago, but company misses analysts' expectations by a long shot.
#
# Storage, servers azur HORSEPOWER dividend update Income per share rise compared with a year ago, but company dearth analysts' awaited by a long shot.
#
#
# [Succeeded / Failed / Skipped / Total] 19 / 1 / 0 / 20:  20% 20/100 [01:06<04:24,  3.30s/it]--------------------------------------------- Result 21 ---------------------------------------------
# Business (62%) --> [38:5:240m[SKIPPED]
#
# IBM to hire even more new workers By the end of the year, the computing giant plans to have its biggest headcount since 1991.
#
#
# [Succeeded / Failed / Skipped / Total] 19 / 1 / 1 / 21:  22% 22/100 [01:08<04:03,  3.13s/it]--------------------------------------------- Result 22 ---------------------------------------------
# Sci/tech (93%) --> [FAILED]
#
# Sun's Looking Glass Provides 3D View Developers get early code for new operating system 'skin' still being crafted.
#
#
# [Succeeded / Failed / Skipped / Total] 19 / 2 / 1 / 22:  22% 22/100 [01:08<04:03,  3.13s/it]--------------------------------------------- Result 23 ---------------------------------------------
# Sci/tech (98%) --> [FAILED]
#
# IBM Chips May Someday Heal Themselves New technology applies electrical fuses to help identify and repair faults.
#
#
# [Succeeded / Failed / Skipped / Total] 19 / 3 / 1 / 23:  24% 24/100 [01:11<03:45,  2.97s/it]--------------------------------------------- Result 24 ---------------------------------------------
# Business (94%) --> [38:5:240m[SKIPPED]
#
# Some People Not Eligible to Get in on Google IPO Google has billed its IPO as a way for everyday people to get in on the process, denying Wall Street the usual stranglehold it's had on IPOs. Public bidding, a minimum of just five shares, an open process with 28 underwriters - all this pointed to a new level of public participation. But this isn't the case.
#
#
# [Succeeded / Failed / Skipped / Total] 19 / 3 / 2 / 24:  24% 24/100 [01:11<03:45,  2.97s/it]--------------------------------------------- Result 25 ---------------------------------------------
# Sci/tech (97%) --> Business (52%)
#
# Rivals Try to Turn Tables on Charles Schwab By MICHAEL LIEDTKE     SAN FRANCISCO (AP) -- With its low prices and iconoclastic attitude, discount stock broker Charles Schwab Corp. (SCH) represented an annoying stone in Wall Street's wing-tipped shoes for decades...
#
# Rivals Try to Turn Tables on Charles Schwab By MICHAEL LIEDTKE     SAN FRANCISCO (HAS) -- With its low prices and iconoclastic attitude, discount stock broker Charles Schwab Corp. (SCH) represented an annoying stone in Wall Street's wing-tipped shoes for decades...
#
#
# [Succeeded / Failed / Skipped / Total] 20 / 3 / 2 / 25:  26% 26/100 [01:14<03:31,  2.86s/it]--------------------------------------------- Result 26 ---------------------------------------------
# Sci/tech (100%) --> [FAILED]
#
# News: Sluggish movement on power grid cyber security Industry cyber security standards fail to reach some of the most vulnerable components of the power grid.\
#
#
# [Succeeded / Failed / Skipped / Total] 20 / 4 / 2 / 26:  26% 26/100 [01:14<03:31,  2.86s/it]--------------------------------------------- Result 27 ---------------------------------------------
# Sports (95%) --> World (50%)
#
# Giddy Phelps Touches Gold for First Time Michael Phelps won the gold medal in the 400 individual medley and set a world record in a time of 4 minutes 8.26 seconds.
#
# Dizzy Phelps Touches Gold for First Times Michael Phelps won the gold trophy in the 400 own potpourri and set a world record in a time of 4 minutes 8.26 seconds.
#
#
# [Succeeded / Failed / Skipped / Total] 21 / 4 / 2 / 27:  28% 28/100 [01:17<03:19,  2.76s/it]--------------------------------------------- Result 28 ---------------------------------------------
# Sports (100%) --> Business (54%)
#
# Tougher rules won't soften Law's game FOXBOROUGH -- Looking at his ridiculously developed upper body, with huge biceps and hardly an ounce of fat, it's easy to see why Ty Law, arguably the best cornerback in football, chooses physical play over finesse. That's not to imply that he's lacking a finesse component, because he can shut down his side of the field much as Deion Sanders ...
#
# Tougher rules won't soften Law's gambling FOXBOROUGH -- Looking at his ridiculously developed upper body, with huge biceps and hardly an ounce of fat, it's easy to see why Ty Law, possibly the dignified suggs in football, chooses physical play over finesse. That's not to proposes that he's deficits a finesse component, because he can shut down his parties of the zoning much as Deion Bowers ...
#
#
# [Succeeded / Failed / Skipped / Total] 22 / 4 / 2 / 28:  28% 28/100 [01:17<03:19,  2.76s/it]--------------------------------------------- Result 29 ---------------------------------------------
# Sports (100%) --> Business (53%)
#
# Shoppach doesn't appear ready to hit the next level With the weeks dwindling until Jason Varitek enters free agency, the Red Sox continue to carefully monitor Kelly Shoppach , their catcher of the future, in his climb toward the majors. The Sox like most of what they have seen at Triple A Pawtucket from Shoppach, though it remains highly uncertain whether he can make the adjustments at the plate ...
#
# Shoppach doesn't emerging allready to minted the next level Usage the weekend dwindling until Jason Varitek enters gratuitous agency, the Red Sox uninterrupted to carefully monitor Kaitlin Shoppach , their recipient of the future, in his climb toward the majors. The Sox like most of what they have consulted at Triple A Pawtucket from Shoppach, while it remains highly uncertain whether he can make the adjustments at the plate ...
#
#
# [Succeeded / Failed / Skipped / Total] 23 / 4 / 2 / 29:  30% 30/100 [01:22<03:11,  2.74s/it]--------------------------------------------- Result 30 ---------------------------------------------
# Sports (100%) --> Business (61%)
#
# Mighty Ortiz makes sure Sox can rest easy Just imagine what David Ortiz could do on a good night's rest. Ortiz spent the night before last with his baby boy, D'Angelo, who is barely 1 month old. He had planned on attending the Red Sox' Family Day at Fenway Park yesterday morning, but he had to sleep in. After all, Ortiz had a son at home, and he ...
#
# Mighty Regis makes sure Sox can surplus easy Equitable imagine what David Ortiz could do on a good night's rest. Velasquez spent the night before last with his baby folks, D'Angelo, who is tad 1 month old. He had programmer on attending the Reed Sox' Parenting Day at Fenway Tunney yesterday morning, but he had to sleep in. After all, Ortiz had a yarns at home, and he ...
#
#
# [Succeeded / Failed / Skipped / Total] 24 / 4 / 2 / 30:  30% 30/100 [01:22<03:11,  2.74s/it]--------------------------------------------- Result 31 ---------------------------------------------
# Sports (100%) --> Sci/tech (55%)
#
# They've caught his eye In  quot;helping themselves, quot; Ricky Bryant, Chas Gessner, Michael Jennings, and David Patten did nothing Friday night to make Bill Belichick's decision on what to do with his receivers any easier.
#
# They've caught his eye In  nbsp;helping themselves, quot; Ricky Randolph, Chas Gessner, Michael Jennings, and David Patten did nothing Friday night to make Bill Belichick's solution on what to do with his receptor any uncomplicated.
#
#
# [Succeeded / Failed / Skipped / Total] 25 / 4 / 2 / 31:  32% 32/100 [01:25<03:02,  2.68s/it]--------------------------------------------- Result 32 ---------------------------------------------
# Sports (100%) --> Business (52%)
#
# Indians Mount Charge The Cleveland Indians pulled within one game of the AL Central lead by beating the Minnesota Twins, 7-1, Saturday night with home runs by Travis Hafner and Victor Martinez.
#
# Indians Mounts Taxes The Sox Indians draws within one bookmaking of the AL Downtown lead by beating the Cleveland Double, 7-1, Domingo bedtime with houses runs by Trav Hafner and Victor Chavez.
#
#
# [Succeeded / Failed / Skipped / Total] 26 / 4 / 2 / 32:  32% 32/100 [01:25<03:02,  2.68s/it]--------------------------------------------- Result 33 ---------------------------------------------
# World (100%) --> Sci/tech (65%)
#
# Sister of man who died in Vancouver police custody slams chief (Canadian Press) Canadian Press - VANCOUVER (CP) - The sister of a man who died after a violent confrontation with police has demanded the city's chief constable resign for defending the officer involved.
#
# Sister of man who died in Vancouver police keeps critique execs (Canadian Pisa) Canadian Journalism - VANCOUVER (PO) - The stepbrother of a humans who died after a violent confrontation with police has demanded the city's chief constable relinquishing for defending the officer involved.
#
#
# [Succeeded / Failed / Skipped / Total] 27 / 4 / 2 / 33:  34% 34/100 [01:28<02:51,  2.59s/it]--------------------------------------------- Result 34 ---------------------------------------------
# World (100%) --> Business (45%)
#
# Man Sought  #36;50M From McGreevey, Aides Say (AP) AP - The man who claims Gov. James E. McGreevey sexually harassed him was pushing for a cash settlement of up to  #36;50 million before the governor decided to announce that he was gay and had an extramarital affair, sources told The Associated Press.
#
# Man Sought  #36;50M From McGreevey, Aides Say (AP) HAD - The man who claims Employees. James E. McGreevey sexually harassed him was pushing for a cash settlement of up to  #36;50 million before the governor decided to announce that he was gay and had an extramarital affair, sources told The Associated Press.
#
#
# [Succeeded / Failed / Skipped / Total] 28 / 4 / 2 / 34:  34% 34/100 [01:28<02:51,  2.59s/it]--------------------------------------------- Result 35 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Explosions Echo Throughout Najaf NAJAF, Iraq - Explosions and gunfire rattled through the city of Najaf as U.S. troops in armored vehicles and tanks rolled back into the streets here Sunday, a day after the collapse of talks - and with them a temporary cease-fire - intended to end the fighting in this holy city...
#
#
# [Succeeded / Failed / Skipped / Total] 28 / 5 / 2 / 35:  36% 36/100 [01:37<02:53,  2.71s/it]--------------------------------------------- Result 36 ---------------------------------------------
# World (100%) --> Sports (39%)
#
# Frail Pope Celebrates Mass at Lourdes LOURDES, France - A frail Pope John Paul II, breathing heavily and gasping at times, celebrated an open-air Mass on Sunday for several hundred thousand pilgrims, many in wheelchairs, at a shrine to the Virgin Mary that is associated with miraculous cures.    At one point he said "help me" in Polish while struggling through his homily in French...
#
# Touchy Pope Celebrates Mass at Mammoth UNWIELDY, Francy - A scarce Pope Johns Palo II, whiff importantly and groan at times, eminent an open-air Mass on Sunday for miscellaneous hundred thousand pilgrimage, many in wheelchairs, at a shrine to the Virgin Mary that is associated with miraculous cures.    At one point he said "contributing me" in Poland while kamp through his papal in Parisian...
#
#
# [Succeeded / Failed / Skipped / Total] 29 / 5 / 2 / 36:  36% 36/100 [01:37<02:53,  2.71s/it]--------------------------------------------- Result 37 ---------------------------------------------
# Business (62%) --> [38:5:240m[SKIPPED]
#
# Venezuela Prepares for Chavez Recall Vote Supporters and rivals warn of possible fraud; government says Chavez's defeat could produce turmoil in world oil market.
#
#
# [Succeeded / Failed / Skipped / Total] 29 / 5 / 3 / 37:  38% 38/100 [01:38<02:40,  2.59s/it]--------------------------------------------- Result 38 ---------------------------------------------
# World (100%) --> Sci/tech (62%)
#
# 1994 Law Designed to Preserve Guard Jobs (AP) AP - A 1994 law strengthened job protections for National Guard and Reserve troops called to active duty. Here are major provisions of the Uniformed Services Employment and Reemployment Rights Act (USERRA).
#
# 1994 Invoice Designed to Preserve Guard Jobs (AP) ACRES - A 1994 law strengthened job protections for National Guard and Reserve sil called to active duty. Here are major provisions of the Uniformed Services Employment and Reemployment Rights Act (USERRA).
#
#
# [Succeeded / Failed / Skipped / Total] 30 / 5 / 3 / 38:  38% 38/100 [01:38<02:40,  2.59s/it]--------------------------------------------- Result 39 ---------------------------------------------
# World (100%) --> Sports (93%)
#
# Iran Warns Its Missiles Can Hit Anywhere in Israel  TEHRAN (Reuters) - A senior Iranian military official said  Sunday Israel and the United States would not dare attack Iran  since it could strike back anywhere in Israel with its latest  missiles, news agencies reported.
#
# Iranians Precaution Its Projectiles Can Hit Whenever in Yehuda  TEHRAN (Newsday) - A alumni Iranian military officials said  Tonight Israeli and the United States would not dare attack Tehran  since it could homers back anywhere in Israel with its past  howitzer, beginner association reported.
#
#
# [Succeeded / Failed / Skipped / Total] 31 / 5 / 3 / 39:  40% 40/100 [01:47<02:40,  2.68s/it]--------------------------------------------- Result 40 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Afghan Army Dispatched to Calm Violence KABUL, Afghanistan - Government troops intervened in Afghanistan's latest outbreak of deadly fighting between warlords, flying from the capital to the far west on U.S. and NATO airplanes to retake an air base contested in the violence, officials said Sunday...
#
#
# [Succeeded / Failed / Skipped / Total] 31 / 6 / 3 / 40:  40% 40/100 [01:47<02:40,  2.68s/it]--------------------------------------------- Result 41 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Johnson Helps D-Backs End Nine-Game Slide (AP) AP - Randy Johnson took a four-hitter into the ninth inning to help the Arizona Diamondbacks end a nine-game losing streak Sunday, beating Steve Trachsel and the New York Mets 2-0.
#
#
# [Succeeded / Failed / Skipped / Total] 31 / 7 / 3 / 41:  42% 42/100 [01:52<02:35,  2.67s/it]--------------------------------------------- Result 42 ---------------------------------------------
# Business (99%) --> Sci/tech (63%)
#
# Retailers Vie for Back-To-School Buyers (Reuters) Reuters - Apparel retailers are hoping their\back-to-school fashions will make the grade among\style-conscious teens and young adults this fall, but it could\be a tough sell, with students and parents keeping a tighter\hold on their wallets.
#
# Storage Vie for Back-To-School Buyers (Reuters) Reuters - Getup retailers are hoping their\back-to-school fashions will make the grade among\style-conscious teens and young adults this fall, but it could\be a tough sell, with students and parents keeping a tighter\hold on their wallets.
#
#
# [Succeeded / Failed / Skipped / Total] 32 / 7 / 3 / 42:  42% 42/100 [01:52<02:35,  2.67s/it]--------------------------------------------- Result 43 ---------------------------------------------
# World (100%) --> Sci/tech (53%)
#
# Politics an Afterthought Amid Hurricane (AP) AP - If Hurricane Charley had struck three years ago, President Bush's tour through the wreckage of this coastal city would have been just the sort of post-disaster visit that other presidents have made to the scenes of storms, earthquakes, floods and fires.
#
# Politics an Afterthought Amid Hurricane (AP) ACRES - If Hurricane Charley had raiding three years ago, Chairmanship Bush's tour through the wreckage of this coastal township would have been just the sort of post-disaster visit that other presidents have made to the scenes of storms, earthquakes, floods and fires.
#
#
# [Succeeded / Failed / Skipped / Total] 33 / 7 / 3 / 43:  44% 44/100 [01:57<02:29,  2.67s/it]--------------------------------------------- Result 44 ---------------------------------------------
# Sci/tech (99%) --> [FAILED]
#
# Spam suspension hits Sohu.com shares (FT.com) FT.com - Shares in Sohu.com, a leading US-listed Chinese internet portal, fell more than 10 per cent on Friday after China's biggest mobile phone network operator imposed a one-year suspension on its multimedia messaging services because of customers being sent spam.
#
#
# [Succeeded / Failed / Skipped / Total] 33 / 8 / 3 / 44:  44% 44/100 [01:57<02:29,  2.67s/it]--------------------------------------------- Result 45 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Erstad's Double Lifts Angels to Win (AP) AP - Darin Erstad doubled in the go-ahead run in the eighth inning, lifting the Anaheim Angels to a 3-2 victory over the Detroit Tigers on Sunday. The win pulled Anaheim within a percentage point of Boston and Texas in the AL wild-card race.
#
#
# [Succeeded / Failed / Skipped / Total] 33 / 9 / 3 / 45:  46% 46/100 [02:05<02:27,  2.73s/it]--------------------------------------------- Result 46 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Drew Out of Braves' Lineup After Injury (AP) AP - Outfielder J.D. Drew missed the Atlanta Braves' game against the St. Louis Cardinals on Sunday night with a sore right quadriceps.
#
#
# [Succeeded / Failed / Skipped / Total] 33 / 10 / 3 / 46:  46% 46/100 [02:05<02:27,  2.73s/it]--------------------------------------------- Result 47 ---------------------------------------------
# World (99%) --> Business (51%)
#
# Venezuelans Flood Polls, Voting Extended  CARACAS, Venezuela (Reuters) - Venezuelans voted in huge  numbers on Sunday in a historic referendum on whether to recall  left-wing President Hugo Chavez and electoral authorities  prolonged voting well into the night.
#
# Venezuelans Flood Polls, Voting Enlargements  CHAVEZ, Chavez (Reuters) - Venezuelans voted in huge  amounts on Sunday in a historic referendum on whether to recall  left-wing Presiding Hugo Chavez and val authorities  prolonged voting well into the tonight.
#
#
# [Succeeded / Failed / Skipped / Total] 34 / 10 / 3 / 47:  48% 48/100 [02:07<02:17,  2.65s/it]--------------------------------------------- Result 48 ---------------------------------------------
# Business (58%) --> [38:5:240m[SKIPPED]
#
# Dell Exits Low-End China Consumer PC Market  HONG KONG (Reuters) - Dell Inc. &lt;DELL.O&gt;, the world's  largest PC maker, said on Monday it has left the low-end  consumer PC market in China and cut its overall growth target  for the country this year due to stiff competition in the  segment.
#
#
# [Succeeded / Failed / Skipped / Total] 34 / 10 / 4 / 48:  48% 48/100 [02:07<02:17,  2.65s/it]--------------------------------------------- Result 49 ---------------------------------------------
# World (100%) --> Sci/tech (75%)
#
# China Says Taiwan Spy Also Operated in U.S. - Media  BEIJING (Reuters) - Beijing on Monday accused a  Chinese-American arrested for spying for Taiwan of building an  espionage network in the United States, and said he could go on  trial very soon.
#
# China Says Formosa Spook Also Utilise in U.S. - Multimedia  RICHLAND (Reuters) - Chengdu on Monday accused a  Chinese-American arrested for spying for Kaohsiung of building an  espionage network in the United States, and said he could go on  trial very soon.
#
#
# [Succeeded / Failed / Skipped / Total] 35 / 10 / 4 / 49:  50% 50/100 [02:10<02:10,  2.61s/it]--------------------------------------------- Result 50 ---------------------------------------------
# Sports (100%) --> Sci/tech (61%)
#
# Another Major Non-Factor Another major, another disappointment for Tiger Woods, the No. 1 ranked player in the world who has not won a major championship since his triumph at the 2002 U.S. Open.
#
# A Key Non-Factor Another grand, another resentment for Tiger Timmer, the Nought. 1 hierarchy gamers in the world who holds not won a key copa since his triumph at the 2002 o.S. Inaugurated.
#
#
# [Succeeded / Failed / Skipped / Total] 36 / 10 / 4 / 50:  50% 50/100 [02:10<02:10,  2.61s/it]--------------------------------------------- Result 51 ---------------------------------------------
# World (100%) --> Sci/tech (52%)
#
# US fighter squadron to be deployed in South Korea next month (AFP) AFP - A squadron of US Air Force F-15E fighters based in Alaska will fly to South Korea next month for temporary deployment aimed at enhancing US firepower on the Korean peninsula, US authorities said.
#
# AMERICANA fighter squadron to ai dispensed in South Corrie next mes (AFP) AFP - A squad of US Air Force F-15E warlike based in Alaska will airplanes to South Hahn next month for temporary deployment intent at enhancing US combustion on the Kure correspondent, AMERICANA schools affirms.
#
#
# [Succeeded / Failed / Skipped / Total] 37 / 10 / 4 / 51:  52% 52/100 [02:18<02:08,  2.67s/it]--------------------------------------------- Result 52 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Johnson Back to His Best as D-Backs End Streak  NEW YORK (Reuters) - Randy Johnson struck out 14 batters in  8 1/3 innings to help the Arizona Diamondbacks end a nine-game  losing streak with a 2-0 win over the host New York Mets in the  National League Sunday.
#
#
# [Succeeded / Failed / Skipped / Total] 37 / 11 / 4 / 52:  52% 52/100 [02:18<02:08,  2.67s/it]--------------------------------------------- Result 53 ---------------------------------------------
# World (100%) --> Business (56%)
#
# Restive Maldives eases curfew after rounding up dissidents (AFP) AFP - A curfew in the capital of the Maldives was eased but parliament sessions were put off indefinitely and emergency rule continued following last week's riots, officials and residents said.
#
# Restive Atoll underestimates curfew after neighborhoods up skeptics (AFP) AFP - para curfew in the investments of the Atoll was minimize but bedroom lecturing were filed off consistently and eventuality regulation unceasing trailing final week's dislocation, officials and residents said.
#
#
# [Succeeded / Failed / Skipped / Total] 38 / 11 / 4 / 53:  54% 54/100 [02:22<02:01,  2.64s/it]--------------------------------------------- Result 54 ---------------------------------------------
# Sci/tech (100%) --> Business (81%)
#
# Vodafone hires Citi for Cesky bid (TheDeal.com) TheDeal.com - The U.K. mobile giant wants to find a way to disentagle the Czech wireless and fixed-line businesses.
#
# Vodafone tenancy Citi for Cesky bid (TheDeal.omg) TheDeal.com - The yeo.potassium. mobile giant craves to find a way to disentagle the Czech walkie and fixed-line businesses.
#
#
# [Succeeded / Failed / Skipped / Total] 39 / 11 / 4 / 54:  54% 54/100 [02:22<02:01,  2.64s/it]--------------------------------------------- Result 55 ---------------------------------------------
# Business (100%) --> World (55%)
#
# Dollar Briefly Hits 4-Wk Low Vs Euro  LONDON (Reuters) - The dollar dipped to a four-week low  against the euro on Monday before rising slightly on  profit-taking, but steep oil prices and weak U.S. data  continued to fan worries about the health of the world's  largest economy.
#
# Dollar Briefly Hits 4-Wk Minimum Five Euro  PICCADILLY (Newsday) - The dollar autumn to a four-week cheaper  against the euro on Shabbat before raise rather on  profit-taking, but brutal petrol prices and lifeless U.p. statistics  continues to poss problems about the sanitation of the world's  largest economies.
#
#
# [Succeeded / Failed / Skipped / Total] 40 / 11 / 4 / 55:  56% 56/100 [02:26<01:55,  2.62s/it]--------------------------------------------- Result 56 ---------------------------------------------
# Sci/tech (54%) --> Business (44%)
#
# Promoting a Shared Vision As Michael Kaleko kept running into people who were getting older and having more vision problems, he realized he could do something about it.
#
# Promoting a Shared Vision As Michael Kaleko kept running into people who were getting older and having more eyes problems, he realized he could do something about it.
#
#
# [Succeeded / Failed / Skipped / Total] 41 / 11 / 4 / 56:  56% 56/100 [02:26<01:55,  2.62s/it]--------------------------------------------- Result 57 ---------------------------------------------
# World (95%) --> Business (56%)
#
# India's Tata expands regional footprint via NatSteel buyout (AFP) AFP - India's Tata Iron and Steel Company Ltd. took a strategic step to expand its Asian footprint with the announcement it will buy the Asia-Pacific steel operations of Singapore's NatSteel Ltd.
#
# India's Tata growth boroughs footprint via NatSteel buyout (AFP) AFP - India's Aunty Iron and Steel Industries Scant. took a strategic step to expand its Asian footprint with the announcement it will buy the Asia-Pacific steel operations of Singapore's NatSteel Scant.
#
#
# [Succeeded / Failed / Skipped / Total] 42 / 11 / 4 / 57:  58% 58/100 [02:32<01:50,  2.63s/it]--------------------------------------------- Result 58 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Delegates Urge Cleric to Pull Out of Najaf BAGHDAD, Iraq - Delegates at Iraq's National Conference called on radical Shiite cleric Muqtada al-Sadr to abandon his uprising against U.S. and Iraqi troops and pull his fighters out of a holy shrine in Najaf...
#
#
# [Succeeded / Failed / Skipped / Total] 42 / 12 / 4 / 58:  58% 58/100 [02:32<01:50,  2.63s/it]--------------------------------------------- Result 59 ---------------------------------------------
# Business (100%) --> World (55%)
#
# Treasuries Slip as Stocks Rally  NEW YORK (Reuters) - U.S. Treasury debt prices slipped on  Monday, though traders characterized the move as profit-taking  rather than any fundamental change in sentiment.
#
# Exchequer Leaflets as Stocks Rally  NEW YONKERS (Newsday) - oder.ies. Hon debt prices slipped on  Shabbat, though smugglers characterised the resettled as profit-taking  even than any decisive changing in sentiment.
#
#
# [Succeeded / Failed / Skipped / Total] 43 / 12 / 4 / 59:  60% 60/100 [02:36<01:44,  2.60s/it]--------------------------------------------- Result 60 ---------------------------------------------
# Business (100%) --> Sci/tech (55%)
#
# Dollar Rises Vs Euro on Asset Flows Data  NEW YORK (Reuters) - The dollar extended gains against the  euro on Monday after a report on flows into U.S. assets showed  enough of a rise in foreign investments to offset the current  account gap for the month.
#
# Dollar Rises Vs Euro on Asset Waterways Database  NEW YORKER (Newsday) - The dollar extended gains against the  euro on Monday after a report on flows into U.ies. assets showed  enough of a rise in foreign investments to offset the current  account gap for the month.
#
#
# [Succeeded / Failed / Skipped / Total] 44 / 12 / 4 / 60:  60% 60/100 [02:36<01:44,  2.60s/it]--------------------------------------------- Result 61 ---------------------------------------------
# Sports (100%) --> Sci/tech (74%)
#
# Sutton Adds Haas, Cink to Ryder Cup Team  MILWAUKEE (Sports Network) - U.S. Ryder Cup captain Hal  Sutton finalized his team on Monday when he announced the  selections of Jay Haas and Stewart Cink as his captain's picks.
#
# Buckingham Addendum Haas, Cink to Ryder Cup Computer  ANAHEIM (Recreational Cyberspace) - U.S. Ryder Cup captain Hal  Sutton finalized his team on Monday when he announced the  selections of Jay Haas and Stewart Cink as his captain's picks.
#
#
# [Succeeded / Failed / Skipped / Total] 45 / 12 / 4 / 61:  62% 62/100 [02:38<01:37,  2.55s/it]--------------------------------------------- Result 62 ---------------------------------------------
# Sports (100%) --> Business (49%)
#
# Haas and Cink Selected for Ryder Cup Team Jay Haas joined Stewart Cink as the two captain's picks for a U.S. team that will try to regain the cup from Europe next month.
#
# Haas and Cink Elections for Ryder Cup Appliance Jay Haas joined Steward Cink as the two captain's picks for a yoo.S. team that will try to regain the cup from Eu next months.
#
#
# [Succeeded / Failed / Skipped / Total] 46 / 12 / 4 / 62:  62% 62/100 [02:38<01:37,  2.55s/it]--------------------------------------------- Result 63 ---------------------------------------------
# Sports (100%) --> Sci/tech (54%)
#
# Natalie Coughlin Wins 100M Backstroke (AP) AP - American Natalie Coughlin won Olympic gold in the 100-meter backstroke Monday night. Coughlin, the only woman ever to swim under 1 minute in the event, finished first in 1 minute, 0.37 seconds. Kirsty Coventry of Zimbabwe, who swims at Auburn University in Alabama, earned the silver in 1:00.50. Laure Manaudou of France took bronze in 1:00.88.
#
# ...
#
#
# [Succeeded / Failed / Skipped / Total] 60 / 16 / 4 / 80:  81% 81/100 [03:34<00:50,  2.64s/it]--------------------------------------------- Result 81 ---------------------------------------------
# World (100%) --> Business (62%)
#
# Kerry Widens Lead in California, Poll Finds (Reuters) Reuters - Democratic challenger John Kerry\has a commanding lead over President Bush in California of 54\percent to 38 percent among likely voters, a poll released on\Tuesday found.
#
# Buchanan Widens Lead in California, Poll Finds (Reuters) Newsday - Republican racer Joon Keri\ai a commanding lead over President Bush in California of 54\percent to 38 percent among likely election, a poll released on\Tuesday found.
#
#
# [Succeeded / Failed / Skipped / Total] 61 / 16 / 4 / 81:  82% 82/100 [03:35<00:47,  2.62s/it]--------------------------------------------- Result 82 ---------------------------------------------
# Sports (100%) --> Sci/tech (53%)
#
# Capacity Crowds at Beach Volleyball Rock the Joint  ATHENS (Reuters) - At the beach volleyball, the 2004  Olympics is a sell-out, foot-stomping success.
#
# Knowledge Crowds at Beaches Bocce Rock the Commons  PIRAEUS (Reuters) - During the golf volleyball, the 2004  Olympus is a sell-out, foot-stomping success.
#
#
# [Succeeded / Failed / Skipped / Total] 62 / 16 / 4 / 82:  83% 83/100 [03:37<00:44,  2.62s/it]--------------------------------------------- Result 83 ---------------------------------------------
# Business (100%) --> World (64%)
#
# Dollar Near Recent Lows, Awaits ZEW/CPI  LONDON (Reuters) - The dollar held steady near this week's  four-week low against the euro on Tuesday with investors  awaiting a German investor confidence survey and U.S. consumer  inflation numbers to shed light on the direction.
#
# Dollar Near Recent Busts, Awaits ZEW/CPI  BELFAST (Newsday) - The dollar held steady near this week's  four-week bas against the euro on Tuesday with capital  awaiting a German funder confidence survey and oder.rs. exertion  inflation numerals to boathouse lamppost on the direction.
#
#
# [Succeeded / Failed / Skipped / Total] 63 / 16 / 4 / 83:  83% 83/100 [03:37<00:44,  2.62s/it]--------------------------------------------- Result 84 ---------------------------------------------
# Sci/tech (97%) --> [38:5:240m[SKIPPED]
#
# Intel to delay product aimed for high-definition TVs SAN FRANCISCO -- In the latest of a series of product delays, Intel Corp. has postponed the launch of a video display chip it had previously planned to introduce by year end, putting off a showdown with Texas Instruments Inc. in the fast-growing market for high-definition television displays.
#
#
# [Succeeded / Failed / Skipped / Total] 63 / 16 / 5 / 84:  85% 85/100 [03:39<00:38,  2.58s/it]--------------------------------------------- Result 85 ---------------------------------------------
# World (97%) --> Business (53%)
#
# Venezuela vote keeps Chavez as president CARACAS -- Venezuelans voted resoundingly to keep firebrand populist Hugo Chavez as their president in a victory that drew noisy reactions yesterday from both sides in the streets. International observers certified the results as clean and accurate.
#
# Venezuela adoption retention Chavez as chairmanship CARACAS -- Venezuelans voted resoundingly to keep firebrand populist Hugo Chavez as their presiding in a victory that drew noisy reactions yesterday from both sides in the sidewalks. International observes certified the results as clean and careful.
#
#
# [Succeeded / Failed / Skipped / Total] 64 / 16 / 5 / 85:  85% 85/100 [03:39<00:38,  2.58s/it]--------------------------------------------- Result 86 ---------------------------------------------
# World (100%) --> [FAILED]
#
# Jailing of HK democrat in China 'politically motivated' (AFP) AFP - Hong Kong democrats accused China of jailing one of their members on trumped-up prostitution charges in a bid to disgrace a political movement Beijing has been feuding with for seven years.
#
#
# [Succeeded / Failed / Skipped / Total] 64 / 17 / 5 / 86:  87% 87/100 [03:42<00:33,  2.56s/it]--------------------------------------------- Result 87 ---------------------------------------------
# Business (100%) --> World (89%)
#
# Kmart Swings to Profit in 2Q; Stock Surges (AP) AP - Shares of Kmart Holding Corp. surged 17 percent Monday after the discount retailer reported a profit for the second quarter and said chairman and majority owner Edward Lampert is now free to invest the company's  #36;2.6 billion in surplus cash.
#
# Kmart Swings to Profit in 2Q; Stock Surges (AP) AP - Shares of Kmart Holding Corp. surged 17 percent Monday after the discount purveyor reported a profit for the second quarter and said chairman and majority owner Edward Lampert is now free to invest the company's  #36;2.6 billion in surplus cash.
#
#
# [Succeeded / Failed / Skipped / Total] 65 / 17 / 5 / 87:  87% 87/100 [03:42<00:33,  2.56s/it]--------------------------------------------- Result 88 ---------------------------------------------
# World (100%) --> Sci/tech (61%)
#
# Fischer's Fiancee: Marriage Plans Genuine (AP) AP - Former chess champion Bobby Fischer's announcement thathe is engaged to a Japanese woman could win him sympathy among Japanese officials and help him avoid deportation to the United States, his fiancee and one of his supporters said Tuesday.
#
# Fischer's Fiancee: Nuptials Plans Genuine (AP) HAS - Antiquated chess champion Bobby Fischer's announcement thathe is commit to a Japanese woman could win him affective among Ueno officials and help him avoid deportation to the United States, his fiancee and one of his amateurs submits Tuesday.
#
#
# [Succeeded / Failed / Skipped / Total] 66 / 17 / 5 / 88:  89% 89/100 [03:45<00:27,  2.54s/it]--------------------------------------------- Result 89 ---------------------------------------------
# World (100%) --> Sports (53%)
#
# U.S. Misses Cut in Olympic 100 Free ATHENS, Greece - Top American sprinters Jason Lezak and Ian Crocker missed the cut in the Olympic 100-meter freestyle preliminaries Tuesday, a stunning blow for a country that had always done well in the event.    Pieter van den Hoogenband of the Netherlands and Australian Ian Thorpe advanced to the evening semifinal a day after dueling teenager Michael Phelps in the 200 freestyle, won by Thorpe...
#
# U.avec. Misses Cut in Olympic 100 Free ATHENS, Greco - Top American sprinters Jason Lezak and Ian Crocker missed the reducing in the Olympic 100-meter freestyle preliminaries Tuesday, a stunning blowing for a country that had always done well in the event.    Pieter van den Hoogenband of the Netherlands and Australian Ian Capitaine advancing to the evening semifinal a day after dueling teenager Michael Philipp in the 200 freestyle, won by Captain...
#
#
# [Succeeded / Failed / Skipped / Total] 67 / 17 / 5 / 89:  89% 89/100 [03:45<00:27,  2.54s/it]--------------------------------------------- Result 90 ---------------------------------------------
# Sci/tech (99%) --> Business (51%)
#
# Consumers Would Pay In Phone Proposal A proposal backed by a coalition of telephone carriers would cut billions of dollars in fees owed by long-distance companies to regional phone giants but would allow the regional companies to make up some of the difference by raising monthly phone bills for millions of consumers. &lt;FONT face="verdana,MS Sans Serif,arial,helvetica" size="-2"\ color="#666666"&gt;&lt;B&gt;-The Washington Post&lt;/B&gt;&lt;/FONT&gt;
#
# Consume Wo Pay In Drew Proposal A proposal backed by a coalition of telephone carriers would cut billions of bullets in taxation owed by long-distance enterprising to regional phone giants but would authorized the regional businessmen to establish up some of the difference by raising monthly drew billings for m of patrons. &lt;FONT face="verdana,SCLEROSIS Without Serif,arial,helvetica" size="-2"\ color="#666666"&gt;&lt;B&gt;-The Washington Post&lieutenant;/B&gt;&ensign;/PERSONAGES&gt;
#
#
# [Succeeded / Failed / Skipped / Total] 68 / 17 / 5 / 90:  91% 91/100 [03:53<00:23,  2.56s/it]--------------------------------------------- Result 91 ---------------------------------------------
# World (100%) --> Business (64%)
#
# U.S. Brokers Cease-fire in Western Afghanistan  KABUL (Reuters) - The United States has brokered a  cease-fire between a renegade Afghan militia leader and the  embattled governor of the western province of Herat,  Washington's envoy to Kabul said Tuesday.
#
# ryu.S. Stockbrokers Cease-fire in Western Kabul  YEMEN (Reuters) - The Unite States is traded a  cease-fire between a mutiny Kabul vigilante steering and the  embattled regulator of the westerly prov of Herat,  Washington's recharged to Peshawar advised Mondays.
#
#
# [Succeeded / Failed / Skipped / Total] 69 / 17 / 5 / 91:  91% 91/100 [03:53<00:23,  2.56s/it]--------------------------------------------- Result 92 ---------------------------------------------
# Business (76%) --> Sci/tech (79%)
#
# Sneaky Credit Card Tactics Keep an eye on your credit card issuers -- they may be about to raise your rates.
#
# Sneaky Appropriation Card Tactics Keep an eye on your credit card issuers -- they may be about to raise your rates.
#
#
# [Succeeded / Failed / Skipped / Total] 70 / 17 / 5 / 92:  93% 93/100 [03:54<00:17,  2.52s/it]--------------------------------------------- Result 93 ---------------------------------------------
# Sci/tech (98%) --> Business (54%)
#
# Intel Delays Launch of Projection TV Chip In another product postponement, semiconductor giant Intel Corp. said it won't be offering a chip for projection TVs by the end of 2004 as it had announced earlier this year.
#
# Intel Delays Launch of Forecasts TELLY Chip In another product stunted, semiconductor giant Intel Eilat. telling it won't be offering a perish for projection TVs by the end of 2004 as it had announced earlier this yr.
#
#
# [Succeeded / Failed / Skipped / Total] 71 / 17 / 5 / 93:  93% 93/100 [03:54<00:17,  2.52s/it]--------------------------------------------- Result 94 ---------------------------------------------
# Business (100%) --> Sci/tech (74%)
#
# Fund pessimism grows NEW YORK (CNN/Money) - Money managers are growing more pessimistic about the economy, corporate profits and US stock market returns, according to a monthly survey by Merrill Lynch released Tuesday.
#
# Money pessimism develops FICTION YONKERS (RNC/Monetary) - Money managers are augmented more pessimist about the economy, corporate profits and OURSELVES stockpiled procurement revenue, commensurate to a monthly snooping by Meryl Lynch releasing Nowadays.
#
#
# [Succeeded / Failed / Skipped / Total] 72 / 17 / 5 / 94:  95% 95/100 [03:59<00:12,  2.52s/it]--------------------------------------------- Result 95 ---------------------------------------------
# Sports (91%) --> World (55%)
#
# Kederis proclaims innocence Olympic champion Kostas Kederis today left hospital ahead of his date with IOC inquisitors claiming his innocence and vowing:  quot;After the crucifixion comes the resurrection. quot; ...
#
# Kederis proclaims innocence Olympic champion Yiannis Kederis wed left hospital ahead of his timetable with IOC interrogators confirming his innocence and promises:  quot;Until the crucifixion comes the resurrection. quot; ...
#
#
# [Succeeded / Failed / Skipped / Total] 73 / 17 / 5 / 95:  95% 95/100 [03:59<00:12,  2.52s/it]--------------------------------------------- Result 96 ---------------------------------------------
# Sports (100%) --> Sci/tech (50%)
#
# Eriksson doesn #39;t feel any extra pressure following scandal NEWCASTLE, England (AP) - England coach Sven-Goran Eriksson said Tuesday he isn #39;t under any extra pressure in the aftermath of a scandal that damaged the Football Association #39;s reputation.
#
# Olson doesn #39;t visualise any augmented voltage wake racket BRIGHTON, Brit (AP) - English tutoring Sven-Goran Nilsson saying Nowadays he isn #39;t under any augmented pressurized in the sequel of a bombshell that lesion the Football Collaborative #39;s reputation.
#
#
# [Succeeded / Failed / Skipped / Total] 74 / 17 / 5 / 96:  97% 97/100 [04:07<00:07,  2.55s/it]--------------------------------------------- Result 97 ---------------------------------------------
# Sports (100%) --> [FAILED]
#
# Injured Heskey to miss England friendly NEWCASTLE, England (AP) - Striker Emile Heskey has pulled out of the England squad ahead of Wednesday #39;s friendly against Ukraine because of a tight hamstring, the Football Association said Tuesday.
#
#
# [Succeeded / Failed / Skipped / Total] 74 / 18 / 5 / 97:  97% 97/100 [04:07<00:07,  2.55s/it]--------------------------------------------- Result 98 ---------------------------------------------
# Business (100%) --> [FAILED]
#
# Staples Profit Up, to Enter China Market  NEW YORK (Reuters) - Staples Inc. &lt;A HREF="http://www.investor.reuters.com/FullQuote.aspx?ticker=SPLS.O target=/stocks/quickinfo/fullquote"&gt;SPLS.O&lt;/A&gt;, the top U.S.  office products retailer, on Tuesday reported a 39 percent jump  in quarterly profit, raised its full-year forecast and said it  plans to enter the fast-growing Chinese market, sending its  shares higher.
#
#
# [Succeeded / Failed / Skipped / Total] 74 / 19 / 5 / 98:  99% 99/100 [04:20<00:02,  2.63s/it]--------------------------------------------- Result 99 ---------------------------------------------
# World (100%) --> Sports (52%)
#
# Delegation Is Delayed Before Reaching Najaf AGHDAD, Iraq, Aug. 17  A delegation of Iraqis was delayed for security reasons today but still intended to visit Najaf to try to convince a rebellious Shiite cleric and his militia to evacuate a shrine in the holy city and end ...
#
# Assignments Constituted Retarded Since Accomplishments Bagdad AGHDAD, Mosul, Augustus. 17  A commissioners of Afghani was postponed for insurance explanation tonight but furthermore destiny to consulted Najaf to quest to plausible a rebelled Shiite episcopalian and his warriors to drained a templar in the santa township and concluded ...
#
#
# [Succeeded / Failed / Skipped / Total] 75 / 19 / 5 / 99: 100% 100/100 [04:22<00:00,  2.63s/it]--------------------------------------------- Result 100 ---------------------------------------------
# Business (100%) --> Sci/tech (60%)
#
# Consumer Prices Down, Industry Output Up  WASHINGTON (Reuters) - U.S. consumer prices dropped in July  for the first time in eight months as a sharp run up in energy  costs reversed, the government said in a report that suggested  a slow rate of interest rate hikes is likely.
#
# Consumer Prices Down, Industry Output Up  WASHINGTON (Reuters) - U.rs. consumer prices dropped in Janvier  for the first time in eight months as a sharp implementing up in vigor  costs quashed, the government said in a notification that recommendation  a slow rate of beware rate hikes is capable.
#
#
# [Succeeded / Failed / Skipped / Total] 76 / 19 / 5 / 100: 100% 100/100 [04:22<00:00,  2.63s/it]
#
# config.json: 100% 665/665 [00:00<00:00, 3.73MB/s]
# model.safetensors: 100% 548M/548M [00:09<00:00, 60.0MB/s]
# generation_config.json: 100% 124/124 [00:00<00:00, 656kB/s]
# vocab.json: 100% 1.04M/1.04M [00:00<00:00, 3.15MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 2.80MB/s]
# tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 3.88MB/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (4678 > 1024). Running this sequence through the model will result in indexing errors
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 76     |
# | Number of failed attacks:     | 19     |
# | Number of skipped attacks:    | 5      |
# | Original accuracy:            | 95.0%  |
# | Accuracy under attack:        | 19.0%  |
# | Attack success rate:          | 80.0%  |
# | Average perturbed word %:     | 25.05% |
# | Average num. words per input: | 43.16  |
# | Avg num queries:              | 373.37 |
# | Average Original Perplexity:  | 66.55  |
# | Average Attack Perplexity:    | 233.02 |
# | Average Attack USE Score:     | 0.82   |
# +-------------------------------+--------+

# %% [markdown]
# #**Robust models**
#
# Adversarial Training.

# %%
# !textattack train --help
# Out:
# 2023-12-17 19:45:43.481438: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 19:45:43.481507: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 19:45:43.481562: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 19:45:44.629501: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-17 19:45:47.382016: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# usage: [python -m] textattack <command> [<args>] train [-h] --model-name-or-path
#                                                        MODEL_NAME_OR_PATH
#                                                        [--model-max-length MODEL_MAX_LENGTH]
#                                                        [--model-num-labels MODEL_NUM_LABELS]
#                                                        [--attack ATTACK] [--task-type TASK_TYPE]
#                                                        --dataset DATASET
#                                                        [--dataset-train-split DATASET_TRAIN_SPLIT]
#                                                        [--dataset-eval-split DATASET_EVAL_SPLIT]
#                                                        [--filter-train-by-labels FILTER_TRAIN_BY_LABELS [FILTER_TRAIN_BY_LABELS ...]]
#                                                        [--filter-eval-by-labels FILTER_EVAL_BY_LABELS [FILTER_EVAL_BY_LABELS ...]]
#                                                        [--num-epochs NUM_EPOCHS]
#                                                        [--num-clean-epochs NUM_CLEAN_EPOCHS]
#                                                        [--attack-epoch-interval ATTACK_EPOCH_INTERVAL]
#                                                        [--early-stopping-epochs EARLY_STOPPING_EPOCHS]
#                                                        [--learning-rate LEARNING_RATE]
#                                                        [--num-warmup-steps NUM_WARMUP_STEPS]
#                                                        [--weight-decay WEIGHT_DECAY]
#                                                        [--per-device-train-batch-size PER_DEVICE_TRAIN_BATCH_SIZE]
#                                                        [--per-device-eval-batch-size PER_DEVICE_EVAL_BATCH_SIZE]
#                                                        [--gradient-accumulation-steps GRADIENT_ACCUMULATION_STEPS]
#                                                        [--random-seed RANDOM_SEED] [--parallel]
#                                                        [--load-best-model-at-end] [--alpha ALPHA]
#                                                        [--num-train-adv-examples NUM_TRAIN_ADV_EXAMPLES]
#                                                        [--query-budget-train QUERY_BUDGET_TRAIN]
#                                                        [--attack-num-workers-per-device ATTACK_NUM_WORKERS_PER_DEVICE]
#                                                        [--output-dir OUTPUT_DIR]
#                                                        [--checkpoint-interval-steps CHECKPOINT_INTERVAL_STEPS]
#                                                        [--checkpoint-interval-epochs CHECKPOINT_INTERVAL_EPOCHS]
#                                                        [--save-last] [--log-to-tb]
#                                                        [--tb-log-dir TB_LOG_DIR] [--log-to-wandb]
#                                                        [--wandb-project WANDB_PROJECT]
#                                                        [--logging-interval-step LOGGING_INTERVAL_STEP]
#
# options:
#   -h, --help            show this help message and exit
#   --model-name-or-path MODEL_NAME_OR_PATH, --model MODEL_NAME_OR_PATH
#                         Name or path of the model we want to create. "lstm" and "cnn" will create
#                         TextAttack's LSTM and CNN models while any other input will be used to
#                         create Transformers model. (e.g."brt-base-uncased"). (default: None)
#   --model-max-length MODEL_MAX_LENGTH
#                         The maximum sequence length of the model. (default: None)
#   --model-num-labels MODEL_NUM_LABELS
#                         The number of labels for classification. (default: None)
#   --attack ATTACK       Attack recipe to use (enables adversarial training) (default: None)
#   --task-type TASK_TYPE
#                         Type of task model is supposed to perform. Options: `classification`,
#                         `regression`. (default: classification)
#   --dataset DATASET     dataset for training; will be loaded from `datasets` library. if dataset
#                         has a subset, separate with a colon. ex: `glue^sst2` or `rotten_tomatoes`
#                         (default: yelp)
#   --dataset-train-split DATASET_TRAIN_SPLIT
#                         train dataset split, if non-standard (can automatically detect 'train'
#                         (default: )
#   --dataset-eval-split DATASET_EVAL_SPLIT
#                         val dataset split, if non-standard (can automatically detect 'dev',
#                         'validation', 'eval') (default: )
#   --filter-train-by-labels FILTER_TRAIN_BY_LABELS [FILTER_TRAIN_BY_LABELS ...]
#                         List of labels to keep in the train dataset and discard all others.
#                         (default: None)
#   --filter-eval-by-labels FILTER_EVAL_BY_LABELS [FILTER_EVAL_BY_LABELS ...]
#                         List of labels to keep in the eval dataset and discard all others.
#                         (default: None)
#   --num-epochs NUM_EPOCHS, --epochs NUM_EPOCHS
#                         Total number of epochs for training. (default: 3)
#   --num-clean-epochs NUM_CLEAN_EPOCHS
#                         Number of epochs to train on the clean dataset before adversarial training
#                         (N/A if --attack unspecified) (default: 1)
#   --attack-epoch-interval ATTACK_EPOCH_INTERVAL
#                         Generate a new adversarial training set every N epochs. (default: 1)
#   --early-stopping-epochs EARLY_STOPPING_EPOCHS
#                         Number of epochs validation must increase before stopping early (-1 for no
#                         early stopping) (default: None)
#   --learning-rate LEARNING_RATE, --lr LEARNING_RATE
#                         Learning rate for Adam Optimization. (default: 5e-05)
#   --num-warmup-steps NUM_WARMUP_STEPS
#                         The number of steps for the warmup phase of linear scheduler. (default:
#                         500)
#   --weight-decay WEIGHT_DECAY
#                         Weight decay (L2 penalty). (default: 0.01)
#   --per-device-train-batch-size PER_DEVICE_TRAIN_BATCH_SIZE
#                         The batch size per GPU/CPU for training. (default: 8)
#   --per-device-eval-batch-size PER_DEVICE_EVAL_BATCH_SIZE
#                         The batch size per GPU/CPU for evaluation. (default: 32)
#   --gradient-accumulation-steps GRADIENT_ACCUMULATION_STEPS
#                         Number of updates steps to accumulate the gradients for, before performing
#                         a backward/update pass. (default: 1)
#   --random-seed RANDOM_SEED
#                         Random seed. (default: 786)
#   --parallel            If set, run training on multiple GPUs. (default: False)
#   --load-best-model-at-end
#                         If set, keep track of the best model across training and load it at the
#                         end. (default: False)
#   --alpha ALPHA         The weight of adversarial loss. (default: 1.0)
#   --num-train-adv-examples NUM_TRAIN_ADV_EXAMPLES
#                         The number of samples to attack when generating adversarial training set.
#                         Default is -1 (which is all possible samples). (default: -1)
#   --query-budget-train QUERY_BUDGET_TRAIN
#                         The max query budget to use when generating adversarial training set.
#                         (default: None)
#   --attack-num-workers-per-device ATTACK_NUM_WORKERS_PER_DEVICE
#                         Number of worker processes to run per device for attack. Same as
#                         `num_workers_per_device` argument for `AttackArgs`. (default: 1)
#   --output-dir OUTPUT_DIR
#                         Directory to output training logs and checkpoints. (default:
#                         ./outputs/2023-12-17-19-45-48-430055)
#   --checkpoint-interval-steps CHECKPOINT_INTERVAL_STEPS
#                         Save model checkpoint after every N updates to the model. (default: None)
#   --checkpoint-interval-epochs CHECKPOINT_INTERVAL_EPOCHS
#                         Save model checkpoint after every N epochs. (default: None)
#   --save-last           If set, save the model at end of training. Can be used with `--load-best-
#                         model-at-end` to save the best model at the end. (default: True)
#   --log-to-tb           If set, log to Tensorboard (default: False)
#   --tb-log-dir TB_LOG_DIR
#                         Path of Tensorboard log directory. (default: None)
#   --log-to-wandb        If set, log to Wandb. (default: False)
#   --wandb-project WANDB_PROJECT
#                         Name of Wandb project for logging. (default: textattack)
#   --logging-interval-step LOGGING_INTERVAL_STEP
#                         Log to Tensorboard/Wandb every N steps. (default: 1)

# %%
# !textattack train --attack clare --model-name-or-path distilbert-base-uncased --dataset ag_news --model-num-labels 4 --model-max-length 180 --per-device-train-batch-size 128 --num-epochs 3 --attack-epoch-interval 1 --num-train-adv-examples 100
# Out:
# 2023-12-17 22:59:41.696267: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 22:59:41.696341: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 22:59:41.696381: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 22:59:43.169668: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# textattack: Loading transformers AutoModelForSequenceClassification: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.weight', 'classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# textattack: Loading datasets dataset ag_news, split train.
# textattack: Loading datasets dataset ag_news, split test.
# If you want to use `RobertaLMHeadModel` as a standalone, add `is_decoder=True.`
# textattack: Unknown if model of class <class 'transformers.models.distilbert.modeling_distilbert.DistilBertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# textattack: Writing logs to ./outputs/2023-12-17-22-59-48-513605/train_log.txt.
# textattack: Wrote original training args to ./outputs/2023-12-17-22-59-48-513605/training_args.json.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# textattack: ***** Running training *****
# textattack:   Num examples = 120000
# textattack:   Num epochs = 3
# textattack:   Num clean epochs = 1
# textattack:   Instantaneous batch size per device = 128
# textattack:   Total train batch size (w. parallel, distributed & accumulation) = 128
# textattack:   Gradient accumulation steps = 1
# textattack:   Total optimization steps = 2816
# textattack: ==========================================================
# textattack: Epoch 1
# textattack: Running clean epoch 1/1
# Iteration:   0% 0/938 [00:00<?, ?it/s]^C

# %%
# !textattack train --attack textfooler --model-name-or-path distilbert-base-uncased --dataset ag_news --model-num-labels 4 --model-max-length 180 --per-device-train-batch-size 128 --num-epochs 3 --attack-epoch-interval 1 --num-train-adv-examples 100 --query-budget 5000
# Out:
# 2023-12-17 22:57:17.051177: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-17 22:57:17.051251: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-17 22:57:17.054693: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-17 22:57:20.487095: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# textattack: Loading transformers AutoModelForSequenceClassification: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'pre_classifier.weight', 'pre_classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# textattack: Loading datasets dataset ag_news, split train.
# textattack: Loading datasets dataset ag_news, split test.
# textattack: Unknown if model of class <class 'transformers.models.distilbert.modeling_distilbert.DistilBertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# textattack: Writing logs to ./outputs/2023-12-17-22-57-30-444936/train_log.txt.
# textattack: Wrote original training args to ./outputs/2023-12-17-22-57-30-444936/training_args.json.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# textattack: ***** Running training *****
# textattack:   Num examples = 120000
# textattack:   Num epochs = 3
# textattack:   Num clean epochs = 1
# textattack:   Instantaneous batch size per device = 128
# textattack:   Total train batch size (w. parallel, distributed & accumulation) = 128
# textattack:   Gradient accumulation steps = 1
# textattack:   Total optimization steps = 2816
# textattack: ==========================================================
# textattack: Epoch 1
# textattack: Running clean epoch 1/1
# Iteration:   0% 0/938 [00:00<?, ?it/s]^C
